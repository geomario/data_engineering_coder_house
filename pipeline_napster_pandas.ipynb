# %% [markdown]
# # Entregable # 1

# %%
from colorama import Back, Fore, Style
import pandas as pd
import requests
import psycopg2
import random
import os

# %%
# Function that requests over HTTP a JSON object from a given URL

JSON = int | str | float | bool | None | dict[str, "JSON"] | list["JSON"]
JSONObject = dict[str, JSON]

def http_get_sync(url: str) -> JSONObject:
    """Synchronously performs an HTTP GET request and returns the JSON response."""
    try :
        print(Back.BLACK + Fore.CYAN + "GET: " + url + Style.RESET_ALL)
        return requests.get(url).json()
    except:
        print(Back.BLACK + Fore.RED + "ERROR: " + url + Style.RESET_ALL)
        return {}

# %%
# The limit parameters for the API calls

API_KEY = '?apikey=MjZkYmFhZTctMjFkZi00NjY3LWEwNGMtZDYzNmQ4YmM3OThi'
OFFSET = 1000  # Number of artists to seed in db

# %%
# The URL for the API call

artist_page_offset = 116 # johnny-cash 212 Bob Dylan
# artist_page_offset = random.randint(0, OFFSET)
napster_url = f'https://napi-v2-2-cloud-run-b3gtd5nmxq-uw.a.run.app/v2.2/artists/top{API_KEY}&limit=1&offset={artist_page_offset}'

# %%
# Get the JSON object from the URL

napster_json = http_get_sync(napster_url)
# Out:
# GET: https://napi-v2-2-cloud-run-b3gtd5nmxq-uw.a.run.app/v2.2/artists/top?apikey=MjZkYmFhZTctMjFkZi00NjY3LWEwNGMtZDYzNmQ4YmM3OThi&limit=1&offset=116

# %%
napster_json
# Out:
# {'artists': [{'type': 'artist',
#    'id': 'art.67317',
#    'href': 'https://api.napster.com/v2.2/artists/art.67317',
#    'name': 'Johnny Cash',
#    'shortcut': 'johnny-cash',
#    'amg': '1837021',
#    'blurbs': ["Cash's trademark baritone growl and disdainful sneer were the crown and scepter he bore as the king of outlaw country music.",
#     'Johnny Cash once admitted that when he was a young boy, gospel songs were the only thing that he liked about going to church.',
#     'Johnny Cash has been inducted into three Halls of Fame: the Songwriters, Country Music, and Rock And Roll.',
#     'Although he has been crowned the king of outlaw country, Cash was only arrested once in his lifetime, for drunk driving.',
#     'Following his passing, Cash\'s daughter had to fight off Preparation H for wanting to use "Ring Of Fire" in a commercial.'],
#    'bios': [{'title': 'Napster                                                                                                                         ',
#      'author': 'Napster',
#      'publishDate': '',
#      'bio': 'You might consider Johnny Cash the original gangster. He sang a song about killing a man "just to watch him die" long before young men began to wear big pants and cap their teeth in gold. His trademark baritone growl and disdainful sneer were the crown and scepter he bore as the king of outlaw country music. Cash\'s unique sound wasn\'t complex by any means. His Southern Gothic-tinged narratives and lighthearted country songs contained similar elements to Woody Guthrie\'s simple ditties. However, nobody but Cash could sing those songs with the burning, heartfelt fever that has made him one of the most influential people in country music. Originally, he wanted to make gospel music after finishing up a Korean War tour of duty in the U.S. Air Force. But after releasing his first single on Sun Records ("Cry Cry Cry" backed with "Hey Porter"), it was perfectly clear that he was a country singer. Cash\'s music has never strayed from what he knew best: rock \'n\' roll\'s rebellion, folk\'s painfully autobiographical sensibility, and country music\'s lovelorn longing. The Man In Black passed away in Nashville, Tenn., on September 12, 2003, due to complications brought on by diabetes. He survived his beloved wife, June Carter Cash, by four months.'}],
#    'albumGroups': {'compilations': ['alb.654799620',
#      'alb.654798529',
#      'alb.654797852',
#      'alb.773204883',
#      'alb.771515339',
#      'alb.771515906',
#      'alb.771218300',
#      'alb.769521738',
#      'alb.769450475',
#      'alb.769163079',
#      'alb.769191176',
#      'alb.768690732',
#      'alb.768604985',
#      'alb.768606550',
#      'alb.768543619',
#      'alb.768387293',
#      'alb.768382979',
#      'alb.768404197',
#      'alb.767854591',
#      'alb.767473718',
#      'alb.767169162',
#      'alb.767289869',
#      'alb.767267393',
#      'alb.767276464',
#      'alb.767274244',
#      'alb.767273489',
#      'alb.766828860',
#      'alb.766822833',
#      'alb.766927918',
#      'alb.766964200',
#      'alb.766728936',
#      'alb.766853841',
#      'alb.766360273',
#      'alb.766347152',
#      'alb.766321467',
#      'alb.765841017',
#      'alb.765828768',
#      'alb.765705225',
#      'alb.765791690',
#      'alb.765698166',
#      'alb.765585678',
#      'alb.765042628',
#      'alb.764793085',
#      'alb.764840123',
#      'alb.764808641',
#      'alb.764429217',
#      'alb.764373042',
#      'alb.764387802',
#      'alb.764135454',
#      'alb.764154745',
#      'alb.764173181',
#      'alb.764217216',
#      'alb.764149703',
#      'alb.761862623',
#      'alb.761767929',
#      'alb.761496440',
#      'alb.761546659',
#      'alb.761496682',
#      'alb.761490171',
#      'alb.761527328',
#      'alb.761492368',
#      'alb.763973130',
#      'alb.763918507',
#      'alb.763948789',
#      'alb.763626128',
#      'alb.763452734',
#      'alb.763627737',
#      'alb.763023667',
#      'alb.763227759',
#      'alb.763312817',
#      'alb.762741442',
#      'alb.762278399',
#      'alb.762378393',
#      'alb.762427142',
#      'alb.762127778',
#      'alb.762130931',
#      'alb.762113899',
#      'alb.762140209',
#      'alb.762138752',
#      'alb.761954260',
#      'alb.761991437',
#      'alb.762002589',
#      'alb.761997620',
#      'alb.761961021',
#      'alb.761989082',
#      'alb.761860891',
#      'alb.761028821',
#      'alb.761027748',
#      'alb.760850085',
#      'alb.760681646',
#      'alb.760512770',
#      'alb.760112908',
#      'alb.759917844',
#      'alb.759930899',
#      'alb.759925840',
#      'alb.759673916',
#      'alb.759703722',
#      'alb.759878408',
#      'alb.759891905',
#      'alb.759452005',
#      'alb.759326029',
#      'alb.759383796',
#      'alb.759188825',
#      'alb.758587024',
#      'alb.758654860',
#      'alb.758613859',
#      'alb.758590644',
#      'alb.758833128',
#      'alb.758592211',
#      'alb.758849132',
#      'alb.758278613',
#      'alb.758058715',
#      'alb.757924616',
#      'alb.757822169',
#      'alb.757834845',
#      'alb.757186500',
#      'alb.757024467',
#      'alb.756797614',
#      'alb.756964749',
#      'alb.756795760',
#      'alb.756404363',
#      'alb.756604467',
#      'alb.756536217',
#      'alb.756536632',
#      'alb.756061609',
#      'alb.755783710',
#      'alb.755818465',
#      'alb.755614765',
#      'alb.755567777',
#      'alb.755356464',
#      'alb.755434377',
#      'alb.755347204',
#      'alb.755237789',
#      'alb.754805361',
#      'alb.754866587',
#      'alb.754864820',
#      'alb.754387903',
#      'alb.754383988',
#      'alb.754119047',
#      'alb.753888930',
#      'alb.753654822',
#      'alb.753213225',
#      'alb.753244216',
#      'alb.752914215',
#      'alb.752833949',
#      'alb.752608750',
#      'alb.752444444',
#      'alb.752484902',
#      'alb.752454947',
#      'alb.752550858',
#      'alb.752487985',
#      'alb.752054151',
#      'alb.751838987',
#      'alb.751882768',
#      'alb.751215273',
#      'alb.750980796',
#      'alb.750730018',
#      'alb.750746223',
#      'alb.750791262',
#      'alb.750564302',
#      'alb.749992855',
#      'alb.750273118',
#      'alb.750063007',
#      'alb.749804595',
#      'alb.749598289',
#      'alb.749323784',
#      'alb.749474653',
#      'alb.749293206',
#      'alb.749163707',
#      'alb.749197369',
#      'alb.749070797',
#      'alb.749081720',
#      'alb.749122765',
#      'alb.748892405',
#      'alb.748700908',
#      'alb.748795714',
#      'alb.748717023',
#      'alb.746825595',
#      'alb.747015780',
#      'alb.747134124',
#      'alb.746289804',
#      'alb.746277224',
#      'alb.746313386',
#      'alb.746255453',
#      'alb.745941587',
#      'alb.746092101',
#      'alb.746024928',
#      'alb.745934363',
#      'alb.746083353',
#      'alb.745635814',
#      'alb.745232736',
#      'alb.745190766',
#      'alb.745362481',
#      'alb.745241886',
#      'alb.744888489',
#      'alb.744486277',
#      'alb.744404681',
#      'alb.742904679',
#      'alb.742644054',
#      'alb.741807265',
#      'alb.741700785',
#      'alb.741213078',
#      'alb.740712724',
#      'alb.739586004',
#      'alb.739589650',
#      'alb.738450219',
#      'alb.738344409',
#      'alb.738338920',
#      'alb.737873190',
#      'alb.737774870',
#      'alb.736723070',
#      'alb.736832903',
#      'alb.736894046',
#      'alb.735767153',
#      'alb.733734657',
#      'alb.733454235',
#      'alb.733203447',
#      'alb.732770833',
#      'alb.732743897',
#      'alb.732279622',
#      'alb.731844180',
#      'alb.731749796',
#      'alb.731208691',
#      'alb.730937014',
#      'alb.730932981',
#      'alb.730646659',
#      'alb.258830031',
#      'alb.428689062',
#      'alb.730150321',
#      'alb.730020937',
#      'alb.730156799',
#      'alb.730014688',
#      'alb.729543361',
#      'alb.729551285',
#      'alb.728480518',
#      'alb.728069999',
#      'alb.727891258',
#      'alb.727794789',
#      'alb.727803313',
#      'alb.727119834',
#      'alb.722689860',
#      'alb.725956194',
#      'alb.725965689',
#      'alb.724998466',
#      'alb.724996888',
#      'alb.725240655',
#      'alb.722396643',
#      'alb.726519991',
#      'alb.726520195',
#      'alb.726519748',
#      'alb.726519653',
#      'alb.724047742',
#      'alb.723813490',
#      'alb.723828170',
#      'alb.723827837',
#      'alb.723847049',
#      'alb.722342237',
#      'alb.722341053',
#      'alb.723509004',
#      'alb.723509062',
#      'alb.723509168',
#      'alb.723509435',
#      'alb.723509302',
#      'alb.723509220',
#      'alb.721615173',
#      'alb.721194127',
#      'alb.720421282',
#      'alb.719855733',
#      'alb.719857735',
#      'alb.720039242',
#      'alb.719963265',
#      'alb.719994199',
#      'alb.719981019',
#      'alb.714293882',
#      'alb.718616230',
#      'alb.718549354',
#      'alb.718123522',
#      'alb.717951647',
#      'alb.717920936',
#      'alb.716136401',
#      'alb.707326301',
#      'alb.705412785',
#      'alb.705275951',
#      'alb.690577460',
#      'alb.706241723',
#      'alb.705439514',
#      'alb.705292422',
#      'alb.705420599',
#      'alb.705438741',
#      'alb.705422616',
#      'alb.705426144',
#      'alb.703682745',
#      'alb.706241489',
#      'alb.703345061',
#      'alb.703344501',
#      'alb.711239136',
#      'alb.707170578',
#      'alb.707151756',
#      'alb.703344253',
#      'alb.703704052',
#      'alb.710032197',
#      'alb.703704900',
#      'alb.707536772',
#      'alb.707537002',
#      'alb.711207903',
#      'alb.711235273',
#      'alb.711191098',
#      'alb.717217325',
#      'alb.717219473',
#      'alb.717223030',
#      'alb.717221657',
#      'alb.717222791',
#      'alb.713418499',
#      'alb.713413514',
#      'alb.713448005',
#      'alb.717375317',
#      'alb.717353359',
#      'alb.710440716',
#      'alb.709574100',
#      'alb.710441189',
#      'alb.710437640',
#      'alb.721058689',
#      'alb.721058420',
#      'alb.716844514',
#      'alb.716765326',
#      'alb.716160734',
#      'alb.716223331',
#      'alb.716310224',
#      'alb.715777510',
#      'alb.715638703',
#      'alb.715112126',
#      'alb.715143445',
#      'alb.713909774',
#      'alb.714729861',
#      'alb.714774136',
#      'alb.714775763',
#      'alb.714779768',
#      'alb.714775945',
#      'alb.714776978',
#      'alb.714433451',
#      'alb.714410218',
#      'alb.714081910',
#      'alb.714083279',
#      'alb.713665734',
#      'alb.713570926',
#      'alb.713105139',
#      'alb.713116875',
#      'alb.710014786',
#      'alb.710316320',
#      'alb.710027923',
#      'alb.710031907',
#      'alb.711978949',
#      'alb.712778953',
#      'alb.711975163',
#      'alb.711882975',
#      'alb.712279170',
#      'alb.711522780',
#      'alb.711126476',
#      'alb.711095012',
#      'alb.712496887',
#      'alb.712497462',
#      'alb.710942984',
#      'alb.710939760',
#      'alb.707273609',
#      'alb.706980879',
#      'alb.705428247',
#      'alb.705291621',
#      'alb.705280391',
#      'alb.705284250',
#      'alb.705284769',
#      'alb.705272147',
#      'alb.706310946',
#      'alb.705284066',
#      'alb.705395776',
#      'alb.703344567',
#      'alb.703329402',
#      'alb.707165870',
#      'alb.706992345',
#      'alb.703295306',
#      'alb.707153460',
#      'alb.708020487',
#      'alb.709582090',
#      'alb.709063373',
#      'alb.703814864',
#      'alb.709577221',
#      'alb.703826947',
#      'alb.707528787',
#      'alb.707520432',
#      'alb.707529189',
#      'alb.707413858',
#      'alb.710341742',
#      'alb.707379850',
#      'alb.707540269',
#      'alb.709067861',
#      'alb.709576219',
#      'alb.710375147',
#      'alb.709455371',
#      'alb.708001880',
#      'alb.707490878',
#      'alb.707436643',
#      'alb.707212808',
#      'alb.707256997',
#      'alb.707301371',
#      'alb.706969205',
#      'alb.706911487',
#      'alb.700331307',
#      'alb.704390701',
#      'alb.704390760',
#      'alb.704391566',
#      'alb.704391625',
#      'alb.699569301',
#      'alb.704390642',
#      'alb.704392134',
#      'alb.706207525',
#      'alb.703393652',
#      'alb.705817566',
#      'alb.702868789',
#      'alb.703395650',
#      'alb.703396791',
#      'alb.703962533',
#      'alb.703382773',
#      'alb.703678568',
#      'alb.699910355',
#      'alb.700243802',
#      'alb.705290777',
#      'alb.703734246',
#      'alb.703784035',
#      'alb.703353278',
#      'alb.703183544',
#      'alb.703133875',
#      'alb.703185805',
#      'alb.702566773',
#      'alb.702628914',
#      'alb.702657168',
#      'alb.700427326',
#      'alb.701489439',
#      'alb.701107514',
#      'alb.700618346',
#      'alb.700575442',
#      'alb.700080264',
#      'alb.700077391',
#      'alb.773067868',
#      'alb.700104137',
#      'alb.700169338',
#      'alb.700075585',
#      'alb.699979501',
#      'alb.660876473',
#      'alb.698355252',
#      'alb.698920978',
#      'alb.698914004',
#      'alb.698923542',
#      'alb.698763703',
#      'alb.698641454',
#      'alb.698658951',
#      'alb.694265051',
#      'alb.694265153',
#      'alb.697933980',
#      'alb.697995420',
#      'alb.697640451',
#      'alb.697039726',
#      'alb.696875791',
#      'alb.693162474',
#      'alb.696487760',
#      'alb.696487626',
#      'alb.695787894',
#      'alb.694988723',
#      'alb.694960047',
#      'alb.694755942',
#      'alb.694759523',
#      'alb.693735017',
#      'alb.693372406',
#      'alb.693346702',
#      'alb.693346368',
#      'alb.692867912',
#      'alb.692497780',
#      'alb.692345660',
#      'alb.692498881',
#      'alb.694889633',
#      'alb.691539160',
#      'alb.691392676',
#      'alb.691112995',
#      'alb.690283025',
#      'alb.688456764',
#      'alb.688452761',
#      'alb.688460215',
#      'alb.690732761',
#      'alb.689560685',
#      'alb.692456178',
#      'alb.692456434',
#      'alb.692456814',
#      'alb.682032449',
#      'alb.689375858',
#      'alb.689351401',
#      'alb.55433411',
#      'alb.689082982',
#      'alb.692174886',
#      'alb.686573756',
#      'alb.688871911',
#      'alb.688867592',
#      'alb.684709119',
#      'alb.684696770',
#      'alb.684710630',
#      'alb.687360421',
#      'alb.685332359',
#      'alb.686244242',
#      'alb.686250235',
#      'alb.686293911',
#      'alb.687637955',
#      'alb.685923577',
#      'alb.686390099',
#      'alb.678607432',
#      'alb.680918872',
#      'alb.680923506',
#      'alb.682216271',
#      'alb.683372972',
#      'alb.684931969',
#      'alb.684846398',
#      'alb.686102264',
#      'alb.686102407',
#      'alb.683660378',
#      'alb.683617830',
#      'alb.683619573',
#      'alb.683618252',
#      'alb.683455371',
#      'alb.681984468',
#      'alb.682488341',
#      'alb.682199571',
#      'alb.682342252',
#      'alb.681943594',
#      'alb.681694683',
#      'alb.681028955',
#      'alb.681037947',
#      'alb.680768076',
#      'alb.680761193',
#      'alb.680289342',
#      'alb.680381742',
#      'alb.680158595',
#      'alb.679989915',
#      'alb.678526097',
#      'alb.680396648',
#      'alb.678399894',
#      'alb.177472680',
#      'alb.678108902',
#      'alb.678122294',
#      'alb.677723424',
#      'alb.677832090',
#      'alb.677830463',
#      'alb.677141898',
#      'alb.672050221',
#      'alb.676036021',
#      'alb.676180860',
#      'alb.672185993',
#      'alb.675621819',
#      'alb.675111222',
#      'alb.674686498',
#      'alb.674355859',
#      'alb.673427274',
#      'alb.673065885',
#      'alb.671658796',
#      'alb.671044517',
#      'alb.671476363',
#      'alb.671334310',
#      'alb.670688968',
#      'alb.671267767',
#      'alb.670724673',
#      'alb.670688656',
#      'alb.670688768',
#      'alb.670689095',
#      'alb.670688874',
#      'alb.671099245',
#      'alb.670935304',
#      'alb.670929368',
#      'alb.670929380',
#      'alb.670928245',
#      'alb.669687059',
#      'alb.661635552',
#      'alb.661635006',
#      'alb.669403037',
#      'alb.667171335',
#      'alb.667172109',
#      'alb.667870536',
#      'alb.667884101',
#      'alb.667878655',
#      'alb.667486616',
#      'alb.667488560',
#      'alb.668341754',
#      'alb.666985770',
#      'alb.666622876',
#      'alb.666649523',
#      'alb.656872316',
#      'alb.659391669',
#      'alb.665890667',
#      'alb.665878921',
#      'alb.665593595',
#      'alb.665377039',
#      'alb.664495428',
#      'alb.656581292',
#      'alb.664154506',
#      'alb.664277788',
#      'alb.664273447',
#      'alb.663448329',
#      'alb.663096422',
#      'alb.663088711',
#      'alb.663061758',
#      'alb.663062665',
#      'alb.663090021',
#      'alb.663087597',
#      'alb.663028086',
#      'alb.656871245',
#      'alb.656584120',
#      'alb.662024064',
#      'alb.661705032',
#      'alb.661359231',
#      'alb.661358058',
#      'alb.661359728',
#      'alb.661367602',
#      'alb.661289621',
#      'alb.656584696',
#      'alb.660877638',
#      'alb.660317935',
#      'alb.660310582',
#      'alb.660258441',
#      'alb.659945453',
#      'alb.659469589',
#      'alb.659153828',
#      'alb.658757541',
#      'alb.658256552',
#      'alb.658255330',
#      'alb.658116376',
#      'alb.656426909',
#      'alb.655220618',
#      'alb.655836277',
#      'alb.655872054',
#      'alb.651090532',
#      'alb.651090419',
#      'alb.651092873',
#      'alb.651093205',
#      'alb.655544887',
#      'alb.651100819',
#      'alb.651100414',
#      'alb.651097783',
#      'alb.651098940',
#      'alb.651095650',
#      'alb.651096069',
#      'alb.655799136',
#      'alb.655248933',
#      'alb.655286729',
#      'alb.655272338',
#      'alb.654890200',
#      'alb.654930800',
#      'alb.654957822',
#      'alb.654930058',
#      'alb.653818655',
#      'alb.654967336',
#      'alb.654784410',
#      'alb.654790121',
#      'alb.654804924',
#      'alb.654804783',
#      'alb.654784105',
#      'alb.654783547',
#      'alb.654789999',
#      'alb.654790199',
#      'alb.654709524',
#      'alb.654709330',
#      'alb.654709632',
#      'alb.654728498',
#      'alb.649993121',
#      'alb.649990377',
#      'alb.649978114',
#      'alb.650000329',
#      'alb.650004950',
#      'alb.650000272',
#      'alb.650000093',
#      'alb.650005496',
#      'alb.650005737',
#      'alb.649999176',
#      'alb.649995365',
#      'alb.649999419',
#      'alb.650005424',
#      'alb.650008786',
#      'alb.654506304',
#      'alb.654505030',
#      'alb.654528228',
#      'alb.654505972',
#      'alb.654506763',
#      'alb.654172920',
#      'alb.654185167',
#      'alb.654217514',
#      'alb.654186720',
#      'alb.654215814',
#      'alb.654184426',
#      'alb.654048227',
#      'alb.654531708',
#      'alb.653993917',
#      'alb.654006974',
#      'alb.654015303',
#      'alb.653904180',
#      'alb.653939617',
#      'alb.654000079',
#      'alb.649355379',
#      'alb.649680932',
#      'alb.649358656',
#      'alb.649354947',
#      'alb.649680365',
#      'alb.649345868',
#      'alb.649362212',
#      'alb.649328757',
#      'alb.649298460',
#      'alb.653198975',
#      'alb.649289223',
#      'alb.653199014',
#      'alb.653863826',
#      'alb.652943533',
#      'alb.652953568',
#      'alb.652954860',
#      'alb.648639884',
#      'alb.648639376',
#      'alb.648641077',
#      'alb.648636940',
#      'alb.648639071',
#      'alb.648638819',
#      'alb.648640443',
#      'alb.648642190',
#      'alb.648642081',
#      'alb.648637970',
#      'alb.648640616',
#      'alb.648640717',
#      'alb.648637780',
#      'alb.648635272',
#      'alb.648641422',
#      'alb.652561640',
#      'alb.652561858',
#      'alb.652606954',
#      'alb.652602219',
#      'alb.652282999',
#      'alb.652281804',
#      'alb.652289935',
#      'alb.652280429',
#      'alb.652254957',
#      'alb.652256810',
#      'alb.652288763',
#      'alb.652022315',
#      'alb.651930504',
#      'alb.652018262',
#      'alb.652022524',
#      'alb.651814793',
#      'alb.651787371',
#      'alb.651787602',
#      'alb.651662553',
#      'alb.651663529',
#      'alb.651661252',
#      'alb.651382536',
#      'alb.651381557',
#      'alb.651331204',
#      'alb.651381973',
#      'alb.651355405',
#      'alb.651403720',
#      'alb.651229329',
#      'alb.651229360',
#      'alb.651229119',
#      'alb.651217823',
#      'alb.651185136',
#      'alb.651185642',
#      'alb.651191816',
#      'alb.651191737',
#      'alb.651191619',
#      'alb.651124188',
#      'alb.648207778',
#      'alb.648231680',
#      'alb.648218678',
#      'alb.648206764',
#      'alb.648194381',
#      'alb.648210401',
#      'alb.648201589',
#      'alb.648200446',
#      'alb.648220007',
#      'alb.648235295',
#      'alb.648189851',
#      'alb.648233417',
#      'alb.648207367',
#      'alb.648209714',
#      'alb.651110206',
#      'alb.651109986',
#      'alb.651114335',
#      'alb.651113454',
#      'alb.651108551',
#      'alb.651125177',
#      'alb.650808110',
#      'alb.650811263',
#      'alb.655092850',
#      'alb.647381496',
#      'alb.647378327',
#      'alb.647372393',
#      'alb.647381729',
#      'alb.647373889',
#      'alb.647373104',
#      'alb.647374107',
#      'alb.647381619',
#      'alb.647384563',
#      'alb.650729346',
#      'alb.650319272',
#      'alb.650319429',
#      'alb.650332736',
#      'alb.650332841',
#      'alb.650333741',
#      'alb.650054678',
#      'alb.650032512',
#      'alb.650077644',
#      'alb.649769934',
#      'alb.649708342',
#      'alb.649827257',
#      'alb.649607274',
#      'alb.649507027',
#      'alb.649495581',
#      'alb.633791097',
#      'alb.649313753',
#      'alb.649348892',
#      'alb.648914057',
#      'alb.648950263',
#      'alb.648931880',
#      'alb.648952952',
#      'alb.648957064',
#      'alb.648687604',
#      'alb.648688112',
#      'alb.648438572',
#      'alb.648434658',
#      'alb.648405494',
#      'alb.648406101',
#      'alb.648431672',
#      'alb.648435778',
#      'alb.648378484',
#      'alb.648199621',
#      'alb.648196654',
#      'alb.648247870',
#      'alb.648207740',
#      'alb.648209655',
#      'alb.648203994',
#      'alb.648164343',
#      'alb.648162814',
#      'alb.648164376',
#      'alb.648170768',
#      'alb.648136586',
#      'alb.648136624',
#      'alb.647703381',
#      'alb.647682117',
#      'alb.647653770',
#      'alb.647703510',
#      'alb.647682984',
#      'alb.647682129',
#      'alb.647704753',
#      'alb.647682180',
#      'alb.647704514',
#      'alb.647705015',
#      'alb.647428568',
#      'alb.647397297',
#      'alb.647397821',
#      'alb.647111905',
#      'alb.647137500',
#      'alb.647112057',
#      'alb.647109514',
#      'alb.647138744',
#      'alb.646718139',
#      'alb.646675852',
#      'alb.646645516',
#      'alb.646669294',
#      'alb.646786922',
#      'alb.646182357',
#      'alb.646144671',
#      'alb.646188159',
#      'alb.646196288',
#      'alb.646183182',
#      'alb.646018312',
#      'alb.646010604',
#      'alb.646017670',
#      'alb.645961967',
#      'alb.645790566',
#      'alb.645815052',
#      'alb.645814868',
#      'alb.645817615',
#      'alb.645652830',
#      'alb.645633608',
#      'alb.645634553',
#      'alb.645635336',
#      'alb.645640483',
#      'alb.645652361',
#      'alb.645652153',
#      'alb.645639928',
#      'alb.645435856',
#      'alb.645466987',
#      'alb.645435561',
#      'alb.645177260',
#      'alb.645177477',
#      'alb.645178571',
#      'alb.644888582',
#      'alb.644888405',
#      'alb.644881934',
#      'alb.644846403',
#      'alb.644758701',
#      'alb.639396479',
#      'alb.644762205',
#      'alb.644758361',
#      'alb.644762404',
#      'alb.644762868',
#      'alb.644697780',
#      'alb.644695936',
#      'alb.644682247',
#      'alb.644683956',
#      'alb.644682962',
#      'alb.635950316',
#      'alb.644449708',
#      'alb.644469348',
#      'alb.644450095',
#      'alb.644468150',
#      'alb.632941435',
#      'alb.644087002',
#      'alb.644138684',
#      'alb.643832562',
#      'alb.643798717',
#      'alb.643833006',
#      'alb.639818755',
#      'alb.639811984',
#      'alb.639826770',
#      'alb.639782321',
#      'alb.639764597',
#      'alb.639789484',
#      'alb.639825325',
#      'alb.639813365',
#      'alb.639779029',
#      'alb.639137968',
#      'alb.638844924',
#      'alb.640701325',
#      'alb.642550676',
#      'alb.640101442',
#      'alb.640068819',
#      'alb.640148394',
#      'alb.640101073',
#      'alb.640136466',
#      'alb.640104797',
#      'alb.640098486',
#      'alb.640102258',
#      'alb.640082575',
#      'alb.639790810',
#      'alb.639816428',
#      'alb.640072480',
#      'alb.639826555',
#      'alb.639789211',
#      'alb.639790030',
#      'alb.639825014',
#      'alb.639137780',
#      'alb.639830961',
#      'alb.638822441',
#      'alb.639812052',
#      'alb.640700508',
#      'alb.638843018',
#      'alb.639725423',
#      'alb.640694175',
#      'alb.640883776',
#      'alb.642527862',
#      'alb.640727553',
#      'alb.638923201',
#      'alb.639822958',
#      'alb.639790418',
#      'alb.639830280',
#      'alb.639822321',
#      'alb.638820475',
#      'alb.640768419',
#      'alb.642495049',
#      'alb.638929305',
#      'alb.639830809',
#      'alb.638840858',
#      'alb.639820073',
#      'alb.639140198',
#      'alb.638840331',
#      'alb.642532646',
#      'alb.638844588',
#      'alb.635911094',
#      'alb.640724454',
#      'alb.635917805',
#      'alb.635918466',
#      'alb.642492196',
#      'alb.639156752',
#      'alb.635936138',
#      'alb.638684360',
#      'alb.639140035',
#      'alb.640886559',
#      'alb.642563583',
#      'alb.638840309',
#      'alb.638953338',
#      'alb.638687903',
#      'alb.640726270',
#      'alb.639159724',
#      'alb.638843168',
#      'alb.642562297',
#      'alb.638692236',
#      'alb.640592249',
#      'alb.639156459',
#      'alb.638823289',
#      'alb.640887646',
#      'alb.640619070',
#      'alb.640698472',
#      ...],
#     'others': ['alb.769646269',
#      'alb.767269300',
#      'alb.775959381',
#      'alb.775811325',
#      'alb.772986908',
#      'alb.772247829',
#      'alb.762768756',
#      'alb.765301191',
#      'alb.771193533',
#      'alb.770307691',
#      'alb.768832339',
#      'alb.763917278',
#      'alb.761010321',
#      'alb.760237641',
#      'alb.768907840',
#      'alb.763153288',
#      'alb.763612128',
#      'alb.763624360',
#      'alb.765039490',
#      'alb.762529807',
#      'alb.761403347',
#      'alb.758290587',
#      'alb.761163547',
#      'alb.761961951',
#      'alb.765727315',
#      'alb.762524147',
#      'alb.764245195',
#      'alb.744116372',
#      'alb.759143201',
#      'alb.758866027',
#      'alb.764134367',
#      'alb.761375747',
#      'alb.748631945',
#      'alb.758561308',
#      'alb.759870304',
#      'alb.756927157',
#      'alb.755435504',
#      'alb.750494864',
#      'alb.756264530',
#      'alb.753045711',
#      'alb.751850088',
#      'alb.754268985',
#      'alb.754103586',
#      'alb.768935157',
#      'alb.354343921',
#      'alb.747807982',
#      'alb.747939362',
#      'alb.744634385',
#      'alb.747644382',
#      'alb.736399237',
#      'alb.742240030',
#      'alb.711187427',
#      'alb.744589202',
#      'alb.730245088',
#      'alb.730347616',
#      'alb.734529814',
#      'alb.713101306',
#      'alb.730260273',
#      'alb.731688669',
#      'alb.724452146',
#      'alb.728722218',
#      'alb.751832081',
#      'alb.721176801',
#      'alb.720504539',
#      'alb.725498486',
#      'alb.722954029',
#      'alb.722511504',
#      'alb.724954555',
#      'alb.727330613',
#      'alb.722954448',
#      'alb.698497544',
#      'alb.722794571',
#      'alb.748384820',
#      'alb.744426830',
#      'alb.723149676',
#      'alb.738998797',
#      'alb.650634724',
#      'alb.708940009',
#      'alb.716902756',
#      'alb.715171526',
#      'alb.718305678',
#      'alb.725013614',
#      'alb.709745391',
#      'alb.719182575',
#      'alb.713767708',
#      'alb.653453366',
#      'alb.650633575',
#      'alb.696623538',
#      'alb.712100989',
#      'alb.713099762',
#      'alb.717277162',
#      'alb.698501898',
#      'alb.715561813',
#      'alb.717477649',
#      'alb.704558677',
#      'alb.703017274',
#      'alb.756615319',
#      'alb.717787236',
#      'alb.703896582',
#      'alb.706048653',
#      'alb.709013506',
#      'alb.689411722',
#      'alb.692116930',
#      'alb.708595080',
#      'alb.324976586',
#      'alb.729145879',
#      'alb.698330725',
#      'alb.706797947',
#      'alb.698316383',
#      'alb.702196024',
#      'alb.690578144',
#      'alb.696782613',
#      'alb.700071694',
#      'alb.717736037',
#      'alb.699949688',
#      'alb.701228181',
#      'alb.696581913',
#      'alb.703309830',
#      'alb.714394208',
#      'alb.690108709',
#      'alb.699417556',
#      'alb.683017632',
#      'alb.693493960',
#      'alb.690578155',
#      'alb.691352484',
#      'alb.687189905',
#      'alb.699771760',
#      'alb.693182565',
#      'alb.689771413',
#      'alb.690932306',
#      'alb.679736563',
#      'alb.688920909',
#      'alb.688504802',
#      'alb.690562702',
#      'alb.691295429',
#      'alb.241936833',
#      'alb.687711653',
#      'alb.691842387',
#      'alb.687711553',
#      'alb.690209777',
#      'alb.688471555',
#      'alb.688351384',
#      'alb.686817530',
#      'alb.691835888',
#      'alb.671156888',
#      'alb.670480512',
#      'alb.682865102',
#      'alb.681897312',
#      'alb.681866898',
#      'alb.686060552',
#      'alb.678584387',
#      'alb.680308005',
#      'alb.685253591',
#      'alb.682236748',
#      'alb.683619274',
#      'alb.683252848',
#      'alb.681618760',
#      'alb.681618236',
#      'alb.680249535',
#      'alb.709731943',
#      'alb.670230083',
#      'alb.677235947',
#      'alb.673333485',
#      'alb.679630813',
#      'alb.678072173',
#      'alb.676140062',
#      'alb.724270883',
#      'alb.679859250',
#      'alb.677724875',
#      'alb.677723876',
#      'alb.677654819',
#      'alb.675218941',
#      'alb.670230048',
#      'alb.675348661',
#      'alb.678266641',
#      'alb.677238552',
#      'alb.675092309',
#      'alb.675218376',
#      'alb.672380798',
#      'alb.672426739',
#      'alb.673780007',
#      'alb.670369102',
#      'alb.672188583',
#      'alb.673197217',
#      'alb.674747555',
#      'alb.673259277',
#      'alb.668531103',
#      'alb.669471838',
#      'alb.637048320',
#      'alb.672381426',
#      'alb.670662089',
#      'alb.707822791',
#      'alb.661636298',
#      'alb.677028378',
#      'alb.667351817',
#      'alb.663254411',
#      'alb.660985609',
#      'alb.665062218',
#      'alb.668362801',
#      'alb.660704009',
#      'alb.665768495',
#      'alb.667826326',
#      'alb.661166237',
#      'alb.664275273',
#      'alb.663991714',
#      'alb.592956689',
#      'alb.662757208',
#      'alb.660386198',
#      'alb.657999785',
#      'alb.758354575',
#      'alb.652252393',
#      'alb.660130380',
#      'alb.659155197',
#      'alb.660756347',
#      'alb.647282664',
#      'alb.653349222',
#      'alb.652164569',
#      'alb.656965156',
#      'alb.648247109',
#      'alb.646088176',
#      'alb.647237986',
#      'alb.654318282',
#      'alb.650623144',
#      'alb.650506798',
#      'alb.646337299',
#      'alb.646075530',
#      'alb.654435465',
#      'alb.646068038',
#      'alb.653639006',
#      'alb.646087998',
#      'alb.683498195',
#      'alb.650864499',
#      'alb.651715153',
#      'alb.646847561',
#      'alb.648395800',
#      'alb.610635359',
#      'alb.603493683',
#      'alb.633792489',
#      'alb.649158230',
#      'alb.636720829',
#      'alb.649853469',
#      'alb.641433842',
#      'alb.633787163',
#      'alb.623427408',
#      'alb.629962637',
#      'alb.637975303',
#      'alb.633795916',
#      'alb.654214939',
#      'alb.647544425',
#      'alb.646117582',
#      'alb.654175451',
#      'alb.654186752',
#      'alb.654216349',
#      'alb.741187769',
#      'alb.630873879',
#      'alb.637968544',
#      'alb.643952715',
#      'alb.644145320',
#      'alb.635164577',
#      'alb.642691435',
#      'alb.628991563',
#      'alb.642633592',
#      'alb.642634243',
#      'alb.639394840',
#      'alb.629373498',
#      'alb.707826979',
#      'alb.314310621',
#      'alb.641452112',
#      'alb.641392747',
#      'alb.627443971',
#      'alb.638453963',
#      'alb.644647637',
#      'alb.655175446',
#      'alb.630822666',
#      'alb.632822449',
#      'alb.636232978',
#      'alb.625338280',
#      'alb.639408201',
#      'alb.740448691',
#      'alb.636906364',
#      'alb.639381428',
#      'alb.613078768',
#      'alb.612953242',
#      'alb.612953522',
#      'alb.612955419',
#      'alb.636060469',
#      'alb.635304744',
#      'alb.657590137',
#      'alb.627553149',
#      'alb.628086504',
#      'alb.635090565',
#      'alb.626943437',
#      'alb.630123549',
#      'alb.628661281',
#      'alb.627414959',
#      'alb.592313116',
#      'alb.620977677',
#      'alb.621345030',
#      'alb.625204099',
#      'alb.632078870',
#      'alb.623962300',
#      'alb.623982322',
#      'alb.625667103',
#      'alb.628986927',
#      'alb.623355824',
#      'alb.629892439',
#      'alb.637624835',
#      'alb.623721864',
#      'alb.627592331',
#      'alb.624308052',
#      'alb.624321538',
#      'alb.617665354',
#      'alb.628087687',
#      'alb.628564543',
#      'alb.611991046',
#      'alb.623394610',
#      'alb.611991844',
#      'alb.620008430',
#      'alb.626460028',
#      'alb.612012397',
#      'alb.620276785',
#      'alb.609444281',
#      'alb.616680958',
#      'alb.619258418',
#      'alb.621419485',
#      'alb.621749826',
#      'alb.592957282',
#      'alb.606931603',
#      'alb.618843126',
#      'alb.619328420',
#      'alb.618860831',
#      'alb.618792359',
#      'alb.620200177',
#      'alb.616412457',
#      'alb.620226919',
#      'alb.623112852',
#      'alb.618646883',
#      'alb.617665793',
#      'alb.619043631',
#      'alb.612772205',
#      'alb.621132679',
#      'alb.617643873',
#      'alb.616058629',
#      'alb.613265415',
#      'alb.621147626',
#      'alb.600384197',
#      'alb.603867979',
#      'alb.614079789',
#      'alb.616178601',
#      'alb.618275530',
#      'alb.604778476',
#      'alb.613803891',
#      'alb.601211570',
#      'alb.611520280',
#      'alb.613001779',
#      'alb.612985586',
#      'alb.606635873',
#      'alb.597100118',
#      'alb.605638701',
#      'alb.610884933',
#      'alb.613550678',
#      'alb.597102985',
#      'alb.603784477',
#      'alb.605797661',
#      'alb.595178527',
#      'alb.597130250',
#      'alb.609358089',
#      'alb.601700519',
#      'alb.605800859',
#      'alb.595243114',
#      'alb.595246027',
#      'alb.614846462',
#      'alb.600369900',
#      'alb.689451398',
#      'alb.605340955',
#      'alb.604038586',
#      'alb.605699621',
#      'alb.600788116',
#      'alb.600180892',
#      'alb.597505387',
#      'alb.597597952',
#      'alb.619571678',
#      'alb.604055751',
#      'alb.604070196',
#      'alb.603278614',
#      'alb.597669371',
#      'alb.602826087',
#      'alb.600180883',
#      'alb.601769680',
#      'alb.592912050',
#      'alb.601293931',
#      'alb.599964470',
#      'alb.732913064',
#      'alb.597800311',
#      'alb.606035997',
#      'alb.597148050',
#      'alb.681049721',
#      'alb.597779709',
#      'alb.604897384',
#      'alb.592304145',
#      'alb.594496281',
#      'alb.606742964',
#      'alb.604872867',
#      'alb.596538391',
#      'alb.610467468',
#      'alb.584093192',
#      'alb.742748072',
#      'alb.584067716',
#      'alb.590934757',
#      'alb.597162603',
#      'alb.591318954',
#      'alb.588169607',
#      'alb.581332878',
#      'alb.588866959',
#      'alb.588026416',
#      'alb.588507300',
#      'alb.589416327',
#      'alb.588029931',
#      'alb.597222061',
#      'alb.579830642',
#      'alb.596834814',
#      'alb.577772760',
#      'alb.585611468',
#      'alb.585580841',
#      'alb.606818896',
#      'alb.585821375',
#      'alb.597530561',
#      'alb.585360740',
#      'alb.578580585',
#      'alb.583724404',
#      'alb.581731599',
#      'alb.579424711',
#      'alb.606424691',
#      'alb.631902585',
#      'alb.588188478',
#      'alb.571908771',
#      'alb.567825504',
#      'alb.576654454',
#      'alb.569898043',
#      'alb.242361068',
#      'alb.573573730',
#      'alb.530700995',
#      'alb.570178458',
#      'alb.703880644',
#      'alb.569229741',
#      'alb.569583751',
#      'alb.562151398',
#      'alb.560751338',
#      'alb.652198343',
#      'alb.670270620',
#      'alb.563640638',
#      'alb.564655990',
#      'alb.560201714',
#      'alb.572858369',
#      'alb.565336699',
#      'alb.564266934',
#      'alb.568121055',
#      'alb.569196146',
#      'alb.559040247',
#      'alb.588987887',
#      'alb.569036601',
#      'alb.701295195',
#      'alb.568072080',
#      'alb.554505642',
#      'alb.563552186',
#      'alb.532651643',
#      'alb.556181781',
#      'alb.557142052',
#      'alb.558736607',
#      'alb.611935190',
#      'alb.555561890',
#      'alb.558932316',
#      'alb.553378920',
#      'alb.532381937',
#      'alb.578754168',
#      'alb.589272781',
#      'alb.539510472',
#      'alb.559171712',
#      'alb.553819304',
#      'alb.555019498',
#      'alb.674106666',
#      'alb.742455738',
#      'alb.549949151',
#      'alb.461855056',
#      'alb.546567634',
#      'alb.546653666',
#      'alb.530005458',
#      'alb.531607570',
#      'alb.548006507',
#      'alb.559338591',
#      'alb.553999383',
#      'alb.543288476',
#      'alb.667967977',
#      'alb.532395197',
#      'alb.538692071',
#      'alb.532191192',
#      'alb.531925837',
#      'alb.611728254',
#      'alb.534233407',
#      'alb.530892642',
#      'alb.530256681',
#      'alb.532564731',
#      'alb.532592342',
#      'alb.519625257',
#      'alb.529686209',
#      'alb.535446087',
#      'alb.667993964',
#      'alb.524381030',
#      'alb.525564898',
#      'alb.532792430',
#      'alb.527170595',
#      'alb.642485006',
#      'alb.527067075',
#      'alb.529965617',
#      'alb.523806007',
#      'alb.524442928',
#      'alb.527983955',
#      'alb.523691741',
#      'alb.530318054',
#      'alb.463359643',
#      'alb.514438540',
#      'alb.667987285',
#      'alb.687372682',
#      'alb.515755125',
#      'alb.516778838',
#      'alb.519668307',
#      'alb.568999187',
#      'alb.515786852',
#      'alb.564376698',
#      'alb.519517987',
#      'alb.519428792',
#      'alb.566723349',
#      'alb.510663103',
#      'alb.514332374',
#      'alb.512632444',
#      'alb.512128057',
#      'alb.509316780',
#      'alb.510675342',
#      'alb.507842562',
#      'alb.508477217',
#      'alb.502021740',
#      'alb.531396905',
#      'alb.681046439',
#      'alb.500658910',
#      'alb.493339381',
#      'alb.502118443',
#      'alb.510931360',
#      'alb.713642431',
#      'alb.499025336',
#      'alb.499854069',
#      'alb.500100713',
#      'alb.500408858',
#      'alb.490127129',
#      'alb.495227436',
#      'alb.497762494',
#      'alb.495534601',
#      'alb.488725995',
#      'alb.499316034',
#      'alb.491842101',
#      'alb.497017863',
#      'alb.492439224',
#      'alb.492737154',
#      'alb.491408931',
#      'alb.487282067',
#      'alb.490382726',
#      'alb.270038748',
#      'alb.274088121',
#      'alb.491786416',
#      'alb.480810120',
#      'alb.488211517',
#      'alb.703966578',
#      'alb.529986313',
#      'alb.482345904',
#      'alb.482442216',
#      'alb.485771333',
#      'alb.611778071',
#      'alb.611797890',
#      'alb.683855941',
#      'alb.476263394',
#      'alb.475196125',
#      'alb.482120459',
#      'alb.484359596',
#      'alb.480521190',
#      'alb.611773777',
#      'alb.462960968',
#      'alb.479978024',
#      'alb.494888169',
#      'alb.473823069',
#      'alb.487543947',
#      'alb.474125225',
#      'alb.473194049',
#      'alb.477446362',
#      'alb.477710810',
#      'alb.628975922',
#      'alb.479351529',
#      'alb.528250608',
#      'alb.471247700',
#      'alb.476527125',
#      'alb.471525123',
#      'alb.460997170',
#      'alb.484953927',
#      'alb.469204598',
#      'alb.466251477',
#      'alb.468202825',
#      'alb.475212034',
#      'alb.601026173',
#      'alb.459652160',
#      'alb.459474551',
#      'alb.459268464',
#      'alb.479374015',
#      'alb.454276798',
#      'alb.452695752',
#      'alb.457881510',
#      'alb.485658791',
#      'alb.446857806',
#      'alb.445591916',
#      'alb.447101840',
#      'alb.445921999',
#      'alb.441787083',
#      'alb.444732175',
#      'alb.443093994',
#      'alb.438918677',
#      'alb.438914043',
#      'alb.436077877',
#      'alb.446832977',
#      'alb.467773721',
#      'alb.435332153',
#      'alb.667972090',
#      'alb.439667444',
#      'alb.435397733',
#      'alb.437366512',
#      'alb.446175926',
#      'alb.433165949',
#      'alb.500076357',
#      'alb.434218300',
#      'alb.435210183',
#      'alb.472840752',
#      'alb.424930539',
#      'alb.612390372',
#      'alb.436456718',
#      'alb.439879188',
#      'alb.464965243',
#      'alb.426054502',
#      'alb.421839201',
#      'alb.434446574',
#      'alb.421765227',
#      'alb.424647708',
#      'alb.421743391',
#      'alb.422668243',
#      'alb.421464446',
#      'alb.417131979',
#      'alb.419056590',
#      'alb.420096812',
#      'alb.418869610',
#      'alb.418915355',
#      'alb.443499479',
#      'alb.664279914',
#      'alb.408146562',
#      'alb.403761047',
#      'alb.414239188',
#      'alb.414986901',
#      'alb.423757227',
#      'alb.422302127',
#      'alb.407836990',
#      'alb.635988710',
#      'alb.689479390',
#      'alb.406045067',
#      'alb.734920882',
#      'alb.406699430',
#      'alb.423367227',
#      'alb.423794972',
#      'alb.287591007',
#      'alb.287585507',
#      'alb.400942318',
#      'alb.679143322',
#      'alb.404871900',
#      'alb.424281336',
#      'alb.397765277',
#      'alb.403381751',
#      'alb.401359407',
#      'alb.401958513',
#      'alb.402437554',
#      'alb.424988615',
#      'alb.502510130',
#      'alb.541226885',
#      'alb.624364227',
#      'alb.369241043',
#      'alb.402466885',
#      'alb.425391012',
#      'alb.398839093',
#      'alb.396637644',
#      'alb.421606930',
#      'alb.423834434',
#      'alb.396947918',
#      'alb.396635419',
#      'alb.394211245',
#      'alb.430692889',
#      'alb.403381399',
#      'alb.394849548',
#      'alb.438495121',
#      'alb.390933520',
#      'alb.386944408',
#      'alb.680810985',
#      'alb.712899427',
#      'alb.391472093',
#      'alb.406007834',
#      'alb.391300962',
#      'alb.389251840',
#      'alb.388120521',
#      'alb.602308347',
#      'alb.602340177',
#      'alb.386956021',
#      'alb.425839083',
#      'alb.454417110',
#      'alb.385842856',
#      'alb.493596935',
#      'alb.671809682',
#      'alb.385710582',
#      'alb.379443171',
#      'alb.386323300',
#      'alb.575595728',
#      'alb.375270468',
#      'alb.425735320',
#      'alb.383189701',
#      'alb.478744370',
#      'alb.478627258',
#      'alb.378911244',
#      'alb.383088590',
#      'alb.612355555',
#      'alb.379546825',
#      'alb.381203657',
#      'alb.427136605',
#      'alb.380070779',
#      'alb.676637005',
#      'alb.373172397',
#      'alb.373173223',
#      'alb.373629915',
#      'alb.375304386',
#      'alb.374072439',
#      'alb.373022067',
#      'alb.373361712',
#      'alb.368225740',
#      'alb.373311959',
#      'alb.369326596',
#      'alb.368626239',
#      'alb.466854373',
#      'alb.371030921',
#      'alb.371025616',
#      'alb.371025918',
#      'alb.447267286',
#      'alb.366129327',
#      'alb.371027221',
#      'alb.428692290',
#      'alb.447266246',
#      'alb.451686726',
#      'alb.365310954',
#      'alb.365288413',
#      'alb.365288362',
#      'alb.364678911',
#      'alb.438995036',
#      'alb.352538646',
#      'alb.358741285',
#      'alb.410882093',
#      'alb.460475574',
#      'alb.359164270',
#      'alb.410261169',
#      'alb.612474473',
#      'alb.360416107',
#      'alb.360417276',
#      'alb.424169803',
#      'alb.630680055',
#      'alb.360572928',
#      'alb.362555289',
#      'alb.356558058',
#      'alb.338377868',
#      'alb.349830917',
#      'alb.350086371',
#      'alb.346052403',
#      'alb.423798513',
#      'alb.387429279',
#      'alb.354322790',
#      'alb.710696996',
#      'alb.428817351',
#      'alb.348014586',
#      'alb.369656088',
#      'alb.431380771',
#      'alb.337025459',
#      'alb.338997581',
#      'alb.336799299',
#      'alb.338157048',
#      'alb.359274973',
#      'alb.624288000',
#      'alb.624174455',
#      'alb.338841852',
#      'alb.330676249',
#      'alb.336578390',
#      'alb.336780464',
#      'alb.416930703',
#      'alb.611879767',
#      'alb.337816912',
#      'alb.337220016',
#      'alb.441580637',
#      'alb.334964662',
#      'alb.329609920',
#      'alb.334770150',
#      'alb.332755691',
#      'alb.330657705',
#      'alb.452516274',
#      'alb.334253436',
#      'alb.335137051',
#      'alb.335563188',
#      'alb.334043189',
#      'alb.331979861',
#      'alb.331369355',
#      'alb.371042327',
#      'alb.666640183',
#      'alb.479946950',
#      'alb.427006954',
#      'alb.329632575',
#      'alb.337237218',
#      'alb.562941487',
#      'alb.431181120',
#      'alb.319389645',
#      'alb.331644251',
#      'alb.326584670',
#      'alb.766231281',
#      'alb.320882606',
#      'alb.322673846',
#      'alb.399096049',
#      'alb.611723652',
#      'alb.329349778',
#      'alb.327808037',
#      'alb.326488165',
#      'alb.324071419',
#      'alb.667941084',
#      'alb.518547246',
#      'alb.319257092',
#      'alb.323525677',
#      'alb.323525904',
#      'alb.323449449',
#      'alb.325026519',
#      'alb.323576569',
#      'alb.324068288',
#      'alb.321708745',
#      'alb.424355605',
#      'alb.421840326',
#      'alb.320597948',
#      'alb.307903254',
#      'alb.307340449',
#      'alb.319156794',
#      'alb.319156353',
#      'alb.323915998',
#      'alb.406539367',
#      'alb.315528376',
#      'alb.318350683',
#      'alb.320558450',
#      'alb.330092637',
#      'alb.611871435',
#      'alb.328011532',
#      'alb.319059308',
#      'alb.424309941',
#      'alb.421868812',
#      'alb.601555557',
#      'alb.700614849',
#      'alb.309368003',
#      'alb.316624146',
#      'alb.317400633',
#      'alb.318650733',
#      'alb.316598050',
#      'alb.316090855',
#      'alb.430315935',
#      'alb.316975413',
#      'alb.421834524',
#      'alb.424412197',
#      'alb.313907462',
#      'alb.314973854',
#      'alb.316022096',
#      'alb.313521707',
#      'alb.714372684',
#      'alb.665104957',
#      'alb.311257006',
#      'alb.686612031',
#      'alb.426165253',
#      'alb.305171852',
#      'alb.306748812',
#      'alb.430613173',
#      'alb.454170044',
#      'alb.316404856',
#      'alb.302015642',
#      'alb.312196270',
#      'alb.304282263',
#      'alb.430527842',
#      'alb.308842878',
#      'alb.485129332',
#      'alb.498557790',
#      'alb.286946395',
#      'alb.703009830',
#      'alb.296396378',
#      'alb.297451841',
#      'alb.411196077',
#      'alb.453988589',
#      'alb.293031113',
#      'alb.296328142',
#      'alb.299573183',
#      'alb.299573838',
#      'alb.292397766',
#      'alb.297188483',
#      'alb.297188637',
#      'alb.432722784',
#      'alb.323535021',
#      'alb.328932185',
#      'alb.337853639',
#      'alb.610699174',
#      'alb.292633133',
#      'alb.531902502',
#      'alb.289790884',
#      'alb.294014148',
#      'alb.283713903',
#      'alb.283693485',
#      'alb.287553031',
#      'alb.281233272',
#      'alb.283714326',
#      'alb.287006683',
#      'alb.286554949',
#      'alb.283868006',
#      'alb.286488196',
#      'alb.284045509',
#      'alb.290565887',
#      'alb.277333714',
#      'alb.285483396',
#      'alb.297558802',
#      'alb.282182174',
#      'alb.279402516',
#      'alb.281323263',
#      'alb.298347051',
#      'alb.410963517',
#      'alb.274581190',
#      'alb.279541937',
#      'alb.432659318',
#      'alb.282668353',
#      'alb.276578262',
#      'alb.276580499',
#      'alb.432406229',
#      'alb.276160449',
#      'alb.270920202',
#      'alb.314969393',
#      'alb.738705416',
#      'alb.270415421',
#      'alb.270425289',
#      'alb.270600008',
#      'alb.269249103',
#      'alb.267459002',
#      'alb.431912988',
#      'alb.267264470',
#      'alb.266357346',
#      'alb.268910122',
#      'alb.263285579',
#      'alb.266006970',
#      'alb.265841611',
#      'alb.266680322',
#      'alb.524630141',
#      'alb.267099151',
#      'alb.465761483',
#      'alb.465779845',
#      'alb.265704904',
#      'alb.464495465',
#      'alb.460046470',
#      'alb.264409601',
#      'alb.266853214',
#      'alb.264740253',
#      'alb.263718363',
#      'alb.269023468',
#      'alb.432731449',
#      'alb.258940166',
#      'alb.397981751',
#      'alb.698673712',
#      'alb.336021027',
#      'alb.253720563',
#      'alb.302709131',
#      'alb.584202200',
#      'alb.720074985',
#      'alb.249551581',
#      'alb.298971198',
#      'alb.274064418',
#      'alb.244932253',
#      'alb.454112418',
#      'alb.243988660',
#      'alb.398106034',
#      'alb.576685102',
#      'alb.432500265',
#      'alb.615115654',
#      'alb.411023734',
#      'alb.237568834',
#      'alb.436016076',
#      'alb.236092247',
#      'alb.564233154',
#      'alb.232818544',
#      'alb.397986085',
#      'alb.666245716',
#      'alb.398034657',
#      ...],
#     'main': ['alb.749166258',
#      'alb.721932290',
#      'alb.722262337',
#      'alb.721565568',
#      'alb.722643432',
#      'alb.721348951',
#      'alb.722298470',
#      'alb.721310019',
#      'alb.717274852',
#      'alb.708998575',
#      'alb.685278676',
#      'alb.685280126',
#      'alb.680399486',
#      'alb.711327230',
#      'alb.677501964',
#      'alb.668655629',
#      'alb.668821220',
#      'alb.667352898',
#      'alb.667352073',
#      'alb.667103256',
#      'alb.658592647',
#      'alb.651308281',
#      'alb.657581048',
#      'alb.655038913',
#      'alb.640571280',
#      'alb.640574554',
#      'alb.644411384',
#      'alb.655498218',
#      'alb.626686595',
#      'alb.624962688',
#      'alb.613499287',
#      'alb.610514014',
#      'alb.619617992',
#      'alb.619607125',
#      'alb.619735029',
#      'alb.619346918',
#      'alb.618768292',
#      'alb.616694076',
#      'alb.615002082',
#      'alb.614570409',
#      'alb.614584493',
#      'alb.611143954',
#      'alb.611439865',
#      'alb.611439557',
#      'alb.601336516',
#      'alb.610998237',
#      'alb.601335361',
#      'alb.583135565',
#      'alb.581526330',
#      'alb.599462079',
#      'alb.580740966',
#      'alb.580458022',
#      'alb.591759160',
#      'alb.594025293',
#      'alb.707591441',
#      'alb.577663064',
#      'alb.569235799',
#      'alb.577551496',
#      'alb.579975077',
#      'alb.569252160',
#      'alb.578826916',
#      'alb.576656687',
#      'alb.606400829',
#      'alb.576668668',
#      'alb.570449878',
#      'alb.606591398',
#      'alb.570475458',
#      'alb.565959011',
#      'alb.619346943',
#      'alb.568550388',
#      'alb.568542302',
#      'alb.544306954',
#      'alb.543573663',
# ...
#      'alb.667117511',
#      'alb.613114901',
#      'alb.561595132',
#      'alb.561593928',
#      'alb.605440606',
#      'alb.599266068',
#      'alb.598954502',
#      'alb.590415736',
#      'alb.594017930',
#      'alb.579244360',
#      'alb.534137973',
#      'alb.530289814',
#      'alb.518202790',
#      'alb.508823870',
#      'alb.512254789',
#      'alb.495656388',
#      'alb.442355650',
#      'alb.420224714',
#      'alb.418941345',
#      'alb.419345700',
#      'alb.409975019',
#      'alb.409158985',
#      'alb.410031216',
#      'alb.414411786',
#      'alb.411309105',
#      'alb.411291268',
#      'alb.410158752',
#      'alb.410158872',
#      'alb.410158916',
#      'alb.409689541',
#      'alb.411291186',
#      'alb.408353557',
#      'alb.409158860',
#      'alb.409137509',
#      'alb.408125318',
#      'alb.408331655',
#      'alb.407461455',
#      'alb.407310346',
#      'alb.407310294',
#      'alb.313221268',
#      'alb.355678347',
#      'alb.343668874',
#      'alb.343665463',
#      'alb.458775815',
#      'alb.319771660',
#      'alb.601937627',
#      'alb.601937694',
#      'alb.601937362',
#      'alb.601937805',
#      'alb.341165949',
#      'alb.343669327',
#      'alb.343669821',
#      'alb.349787753',
#      'alb.349787837',
#      'alb.349806001',
#      'alb.349788084',
#      'alb.349806455',
#      'alb.349806471',
#      'alb.334209827',
#      'alb.339005422',
#      'alb.343858135',
#      'alb.339005262',
#      'alb.339005298',
#      'alb.339005560',
#      'alb.339005588',
#      'alb.372973823',
#      'alb.369571891',
#      'alb.312362089',
#      'alb.314443787',
#      'alb.529674715',
#      'alb.288247512',
#      'alb.288256821',
#      'alb.280728250',
#      'alb.278603828',
#      'alb.267278974',
#      'alb.262948560',
#      'alb.262966714',
#      'alb.262948280',
#      'alb.262948328',
#      'alb.254752234',
#      'alb.236228263',
#      'alb.230725141',
#      'alb.227842009',
#      'alb.227084297',
#      'alb.226031608',
#      'alb.225117351',
#      'alb.224692768',
#      'alb.224690362',
#      'alb.216965563',
#      'alb.216965617',
#      'alb.207057391',
#      'alb.204275488',
#      'alb.204275751',
#      'alb.205834856',
#      'alb.189104190',
#      'alb.202315463',
#      'alb.205834963',
#      'alb.203429947',
#      'alb.203367110',
#      'alb.193113757',
#      'alb.331217085',
#      'alb.203434114',
#      'alb.202334083',
#      'alb.194403694',
#      'alb.202368180',
#      'alb.205684516',
#      'alb.202439893',
#      'alb.202012536',
#      'alb.215273047',
#      'alb.189208551',
#      'alb.189167130',
#      'alb.189209643',
#      'alb.189167203',
#      'alb.195149689',
#      'alb.195216932',
#      'alb.197387052',
#      'alb.195144396',
#      'alb.200801607',
#      'alb.195888249',
#      'alb.195150267',
#      'alb.197386238',
#      'alb.195894621',
#      'alb.200153935',
#      'alb.195220298',
#      'alb.200536912',
#      'alb.191258089',
#      'alb.193740149',
#      'alb.195219784',
#      'alb.201411459',
#      'alb.187627741',
#      'alb.201410525',
#      'alb.189968821',
#      'alb.187628464',
#      'alb.186123042',
#      'alb.192031625',
#      'alb.195461237',
#      'alb.192030367',
#      'alb.187628704',
#      'alb.189861095',
#      'alb.190119433',
#      'alb.193610792',
#      'alb.191100046',
#      'alb.198517275',
#      'alb.192032133',
#      'alb.190119253',
#      'alb.191352724',
#      'alb.183115138',
#      'alb.183126236',
#      'alb.180066290',
#      'alb.373224869',
#      'alb.183136288',
#      'alb.171393606',
#      'alb.178764254',
#      'alb.175110668',
#      'alb.175108247',
#      'alb.178763555',
#      'alb.180124536',
#      'alb.179828359',
#      'alb.172358720',
#      'alb.172358429',
#      'alb.172355576',
#      'alb.169267438',
#      'alb.170492173',
#      'alb.240259915',
#      'alb.240255677',
#      'alb.240255738',
#      'alb.240255807',
#      'alb.240255822',
#      'alb.240255936',
#      'alb.240255951',
#      'alb.170276083',
#      'alb.176508134',
#      'alb.171861148',
#      'alb.170451193',
#      'alb.170350609',
#      'alb.167974064',
#      'alb.177963647',
#      'alb.176149614',
#      'alb.174173924',
#      'alb.182073950',
#      'alb.163807799',
#      'alb.166315346',
#      'alb.163845578',
#      'alb.179152104',
#      'alb.168225554',
#      'alb.161425029',
#      'alb.160868527',
#      'alb.175270206',
#      'alb.175270306',
#      'alb.152658250',
#      'alb.152658264',
#      'alb.152658292',
#      'alb.152658306',
#      'alb.152658334',
#      'alb.152658348',
#      'alb.175272495',
#      'alb.175271457',
#      'alb.146932881',
#      'alb.149859349',
#      'alb.148099266',
#      'alb.147247804',
#      'alb.148100279',
#      'alb.148099316',
#      'alb.149436962',
#      'alb.149432569',
#      'alb.149434266',
#      'alb.149434280',
#      'alb.147658318',
#      'alb.145565359',
#      'alb.144739664',
#      'alb.142989442',
#      'alb.146148865',
#      'alb.142988329',
#      'alb.144263043',
#      'alb.142833400',
#      'alb.144261851',
#      'alb.142832618',
#      'alb.142833683',
#      'alb.143442230',
#      'alb.141978861',
#      'alb.141978811',
#      'alb.141979169',
#      'alb.143066273',
#      'alb.141554570',
#      'alb.141601140',
#      'alb.146352930',
#      'alb.140588706',
#      'alb.139867078',
#      'alb.139874631',
#      'alb.140590817',
#      'alb.140587914',
#      'alb.139874366',
#      'alb.139865332',
#      'alb.139874389',
#      'alb.139865064',
#      'alb.138728170',
#      'alb.138683777',
#      'alb.138689122',
#      'alb.138702271',
#      'alb.143368658',
#      'alb.138702650',
#      'alb.137549711',
#      'alb.138687886',
#      'alb.137549408',
#      'alb.138687232',
#      'alb.138684130',
#      'alb.138749819',
#      'alb.138728906',
#      'alb.138728920',
#      'alb.136870498',
#      'alb.136873548',
#      'alb.136875979',
#      'alb.136860122',
#      'alb.141150636',
#      'alb.136864966',
#      'alb.136863360',
#      'alb.136854556',
#      'alb.136854860',
#      'alb.136873834',
#      'alb.136860970',
#      'alb.136536808',
#      'alb.136866497',
#      'alb.143295153',
#      'alb.136867493',
#      'alb.139058403',
#      'alb.135602691',
#      'alb.138641671',
#      'alb.138498415',
#      'alb.138645206',
#      'alb.138498255',
#      'alb.138498446',
#      'alb.138500893',
#      'alb.138687277',
#      'alb.150582191',
#      'alb.318291206',
#      'alb.609193278',
#      'alb.392807835',
#      'alb.135602235',
#      'alb.135603430',
#      'alb.135603604',
#      'alb.135233849',
#      'alb.136854022',
#      'alb.134732065',
#      'alb.134730821',
#      'alb.134733718',
#      'alb.134733165',
#      'alb.135291391',
#      'alb.134735118',
#      'alb.134736040',
#      'alb.134728526',
#      'alb.134730287',
#      'alb.133628041',
#      'alb.134733375',
#      'alb.133626605',
#      'alb.133626411',
#      'alb.133329132',
#      'alb.133329100',
#      'alb.133328368',
#      'alb.133627725',
#      'alb.133329146',
#      'alb.133328326',
#      'alb.133328946',
#      'alb.133328651',
#      'alb.133194435',
#      'alb.131360003',
#      'alb.131358194',
#      'alb.131348879',
#      'alb.131352064',
#      'alb.131354993',
#      'alb.131354335',
#      'alb.131348942',
#      'alb.131353245',
#      'alb.131360559',
#      'alb.131363789',
#      'alb.131358289',
#      'alb.131348773',
#      'alb.131357722',
#      'alb.131357960',
#      'alb.131434260',
#      'alb.165063131',
#      'alb.172026014',
#      'alb.131357206',
#      'alb.133743151',
#      'alb.127151035',
#      'alb.127153624',
#      'alb.123580609',
#      'alb.125507205',
#      'alb.121292418',
#      'alb.122066783',
#      'alb.122828239',
#      'alb.125208830',
#      'alb.124326899',
#      'alb.123559841',
#      'alb.121941794',
#      'alb.120498154',
#      'alb.120581383',
#      'alb.120314998',
#      'alb.136886187',
#      'alb.137426717',
#      'alb.122802702',
#      'alb.116702109',
#      'alb.116092193',
#      'alb.112158335',
#      'alb.109983873',
#      'alb.109773091',
#      'alb.109983522',
#      'alb.110139160',
#      'alb.108843464',
#      'alb.395993377',
#      'alb.608335873',
#      'alb.112110333',
#      'alb.111973635',
#      'alb.119324768',
#      'alb.138708404',
#      'alb.296681779',
#      'alb.533593407',
#      'alb.601756255',
#      'alb.105623143',
#      'alb.105086730',
#      'alb.118294238',
#      'alb.104733001',
#      'alb.104741327',
#      'alb.83770104',
#      'alb.118107838',
#      'alb.104855884',
#      'alb.71313733',
#      'alb.175486985',
#      'alb.212220834',
#      'alb.135316707',
#      'alb.109379825',
#      'alb.110228321',
#      'alb.110244808',
#      'alb.110230848',
#      'alb.110753247',
#      'alb.138148730',
#      'alb.162508406',
#      'alb.175095104',
#      'alb.426096666',
#      'alb.70506294',
#      'alb.110582131',
#      'alb.111884430',
#      'alb.112131029',
#      'alb.129623695',
#      'alb.138687263',
#      'alb.175486821',
#      'alb.118125084',
#      'alb.118265653',
#      'alb.118093488',
#      'alb.117985346',
#      'alb.132671306',
#      'alb.139644085',
#      'alb.140337808',
#      'alb.68842723',
#      'alb.69458507',
#      'alb.66315049',
#      'alb.70769644',
#      'alb.71684459',
#      'alb.69582119',
#      'alb.69582131',
#      'alb.69582145',
#      'alb.351252778',
#      'alb.351258260',
#      'alb.351267967',
#      'alb.601755710',
#      'alb.70555255',
#      'alb.71451885',
#      'alb.67107191',
#      'alb.68112375',
#      'alb.68113297',
#      'alb.66650843',
#      'alb.70670713',
#      'alb.70670824',
#      'alb.118149374',
#      'alb.118098414',
#      'alb.215287024',
#      'alb.601756228',
#      'alb.63652289',
#      'alb.118267855',
#      'alb.217675390',
#      'alb.227290758',
#      'alb.601755285',
#      'alb.61236570',
#      'alb.63652311',
#      'alb.70699780',
#      'alb.63397115',
#      'alb.60825838',
#      'alb.118256754',
#      'alb.52724430',
#      'alb.68947941',
#      'alb.68710806',
#      'alb.65795705',
#      'alb.118302808',
#      'alb.59090688',
#      'alb.65802297',
#      'alb.71313277',
#      'alb.135783196',
#      'alb.167773670',
#      'alb.69191269',
#      'alb.60843257',
#      'alb.70951975',
#      'alb.108095975',
#      'alb.112112618',
#      'alb.118251469',
#      'alb.118168915',
#      'alb.118115174',
#      'alb.118160621',
#      'alb.118161443',
#      'alb.118161707',
#      'alb.118162464',
#      'alb.601756128',
#      'alb.60740172',
#      'alb.118125946',
#      'alb.64444554',
#      'alb.64425493',
#      'alb.71695928',
#      'alb.47744220',
#      'alb.146544996',
#      'alb.44502941',
#      'alb.44577374',
#      'alb.62650075',
#      'alb.67118217',
#      'alb.53747173',
#      'alb.601026114',
#      'alb.58488457',
#      'alb.61696559',
#      'alb.62913305',
#      'alb.114343214',
#      'alb.55306773',
#      'alb.42586427',
#      'alb.41811280',
#      'alb.65644557',
#      'alb.66153509',
#      'alb.66298429',
#      'alb.118007662',
#      'alb.66148797',
#      'alb.62656940',
#      'alb.65103061',
#      'alb.65903066',
#      'alb.65944338',
#      'alb.66132868',
#      'alb.65646397',
#      'alb.76179742',
#      'alb.31969703',
#      'alb.65851188',
#      'alb.65076858',
#      'alb.65070255',
#      'alb.65121911',
#      'alb.66952754',
#      'alb.366963507',
#      'alb.62350049',
#      'alb.62175493',
#      'alb.62794808',
#      'alb.66954005',
#      'alb.71313958',
#      'alb.118152380',
#      'alb.177880035',
#      'alb.178184433',
#      'alb.215286985',
#      'alb.290345085',
#      'alb.300301284',
#      'alb.317590841',
#      'alb.601756115',
#      'alb.65089876',
#      'alb.65550160',
#      'alb.65642582',
#      'alb.69216192',
#      'alb.69322428',
#      'alb.364274769',
#      'alb.29433352',
#      'alb.62154032',
#      'alb.69457362',
#      'alb.118252227',
#      'alb.133295815',
#      'alb.138498315',
#      'alb.217675429',
#      'alb.392795905',
#      'alb.609222234',
#      'alb.689250234',
#      'alb.23227039',
#      'alb.111044477',
#      'alb.373769060',
#      'alb.146495029',
#      'alb.132619066',
#      'alb.132629574',
#      'alb.132733991',
#      'alb.132806609',
#      'alb.132734501',
#      'alb.132734515',
#      'alb.132721032',
#      'alb.132527299',
#      'alb.140988489',
#      'alb.139566742',
#      'alb.140891444',
#      'alb.140120225',
#      'alb.139431204',
#      'alb.139457301',
#      'alb.139487212',
#      'alb.162221016',
#      'alb.162520185',
#      'alb.162492259',
#      'alb.175051545',
#      'alb.175022087',
#      'alb.175059052',
#      'alb.64823323',
#      'alb.23362564',
#      'alb.23362631',
#      'alb.64132896',
#      'alb.118148903',
#      'alb.118131196',
#      'alb.56387949',
#      'alb.56400778',
#      'alb.250593469',
#      'alb.57387937',
#      'alb.57389362',
#      'alb.57901818',
#      'alb.57900078',
#      'alb.252774745',
#      'alb.122236582',
#      'alb.56581454',
#      'alb.56581717',
#      'alb.135718822',
#      'alb.57973354',
#      'alb.57974834',
#      'alb.70643158',
#      'alb.68294581',
#      'alb.69616416',
#      'alb.601756565',
#      'alb.601756590',
#      'alb.601756655',
#      'alb.57676769',
#      'alb.437926135',
#      'alb.601755699',
#      'alb.601756358',
#      'alb.602021074',
#      'alb.601685094',
#      'alb.601756315',
#      'alb.601756328',
#      'alb.601756616',
#      'alb.601756629',
#      'alb.601756642',
#      'alb.600657980',
#      'alb.601756242',
#      'alb.601685548',
#      'alb.601685544',
#      'alb.58847008',
#      'alb.63672680',
#      'alb.136921825',
#      'alb.601031947',
#      'alb.601756561',
#      'alb.601028502',
#      'alb.58360362',
#      'alb.58310781',
#      'alb.62708897',
#      'alb.63159636',
#      'alb.69458911',
#      'alb.108597711',
#      'alb.109558259',
#      'alb.110760666',
#      'alb.118224393',
#      'alb.118109917',
#      'alb.120177273',
#      'alb.122952756',
#      'alb.136885108',
#      'alb.136387758',
#      'alb.136386414',
#      'alb.138645151',
#      'alb.138498328',
#      'alb.154003869',
#      'alb.162310432',
#      'alb.175488605',
#      'alb.175044203',
#      'alb.177898085',
#      'alb.186624426',
#      'alb.201400957',
#      'alb.217674621',
#      'alb.318294658',
#      'alb.601703579',
#      'alb.601027937',
#      'alb.601685799',
#      'alb.601031032',
#      'alb.392807926',
#      'alb.601755633',
#      'alb.601756273',
#      'alb.601685580',
#      'alb.712562305',
#      'alb.601755275',
#      'alb.601756150',
#      'alb.601028381',
#      'alb.601755829',
#      'alb.601756070',
#      'alb.601755629',
#      'alb.601756112']},
#    'links': {'albums': {'href': 'https://api.napster.com/v2.2/artists/art.67317/albums'},
#     'images': {'href': 'https://api.napster.com/v2.2/artists/art.67317/images'},
#     'posts': {'href': 'https://api.napster.com/v2.2/artists/art.67317/posts'},
#     'topTracks': {'href': 'https://api.napster.com/v2.2/artists/art.67317/tracks/top'},
#     'genres': {'ids': ['g.337',
#       'g.407',
#       'g.350',
#       'g.458',
#       'g.76',
#       'g.5',
#       'g.130',
#       'g.131',
#       'g.446',
#       'g.292',
#       'g.409',
#       'g.75',
#       'g.115',
#       'g.121',
#       'g.100',
#       'g.438',
#       'g.67',
#       'g.112',
#       'g.442',
#       'g.197',
#       'g.71',
#       'g.155',
#       'g.262',
#       'g.299',
#       'g.42'],
#      'href': 'https://api.napster.com/v2.2/genres/g.337,g.407,g.350,g.458,g.76,g.5,g.130,g.131,g.446,g.292,g.409,g.75,g.115,g.121,g.100,g.438,g.67,g.112,g.442,g.197,g.71,g.155,g.262,g.299,g.42'},
#     'stations': {'ids': ['sas.67317'],
#      'href': 'https://api.napster.com/v2.2/stations/sas.67317'},
#     'contemporaries': {'ids': ['art.962',
#       'art.3143',
#       'art.3657',
#       'art.4096',
#       'art.6043',
#       'art.39684',
#       'art.61022',
#       'art.5416',
#       'art.38206'],
#      'href': 'https://api.napster.com/v2.2/artists/art.962,art.3143,art.3657,art.4096,art.6043,art.39684,art.61022,art.5416,art.38206'},
#     'followers': {'ids': ['art.958',
#       'art.2283',
#       'art.7112',
#       'art.36201',
#       'art.42556',
#       'art.44568',
#       'art.55771',
#       'art.61501',
#       'art.61503',
#       'art.68439',
#       'art.12273525',
#       'art.66740'],
#      'href': 'https://api.napster.com/v2.2/artists/art.958,art.2283,art.7112,art.36201,art.42556,art.44568,art.55771,art.61501,art.61503,art.68439,art.12273525,art.66740'},
#     'influences': {'ids': ['art.154',
#       'art.1623',
#       'art.3482',
#       'art.4631',
#       'art.68463'],
#      'href': 'https://api.napster.com/v2.2/artists/art.154,art.1623,art.3482,art.4631,art.68463'},
#     'relatedProjects': {'ids': ['art.14263', 'art.44783', 'art.63324'],
#      'href': 'https://api.napster.com/v2.2/artists/art.14263,art.44783,art.63324'}}}],
#  'meta': {'totalCount': 1000, 'returnedCount': 1}}

# %%
# Get all the keys inside artist object
for key in napster_json['artists'][0].keys():
    print(key)
# Out:
# type
# id
# href
# name
# shortcut
# amg
# blurbs
# bios
# albumGroups
# links

# %%
# Check shortcut for artist name
napster_json['artists'][0]['shortcut']
# Out:
# 'johnny-cash'

# %% [markdown]
# # Creating Table
#
# The table for the artist, creates an Artist. Each artist has an ID, type, blurbs, name, hred and shorcut.
#
# ## Artist Table
#
# ![Artist Table](images/artist_table.png)
#
# # Data Structures
#
# id = string
# type = string
# href = string
# name = string
# shortcut = string

# %%
# Import environment variables

host = os.environ['HOST']
port = os.environ['PORT']
user = os.environ['USER']
password = os.environ['PASSWORD']
database = os.environ['DATABASE']

# %%
# Create a connection to the database

try:
    conn = psycopg2.connect(
        host=host,
        port=port,
        user=user,
        password=password,
        database=database
    )
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Connection to database" + Style.RESET_ALL)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Connection to database" + Style.RESET_ALL)
# Out:
# SUCCESS: Connection to database

# %%
# Create a cursor to execute SQL commands

try:
    cur = conn.cursor()
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Cursor created" + Style.RESET_ALL)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Cursor not created" + Style.RESET_ALL)
# Out:
# SUCCESS: Cursor created

# %%
# Check the connection
personal_schema = os.environ['PERSONAL_SCHEMA']

#  Check schema exists from CODER
cur.execute(f"SELECT * FROM information_schema.tables WHERE table_schema = '{personal_schema}';")
print(cur.fetchall())
# Out:
# [('data-engineer-database', 'marm1984_coderhouse', 'artist_napster', 'BASE TABLE', None, None, None, None, None), ('data-engineer-database', 'marm1984_coderhouse', 'artist', 'BASE TABLE', None, None, None, None, None)]

# %%
# Drop table if exists

cur.execute(f"DROP TABLE IF EXISTS {personal_schema}.artist;")

# %%
# Create a table for artists

try:
    cur.execute(f"""
                CREATE TABLE IF NOT EXISTS {personal_schema}.artist (
                    id VARCHAR(255) PRIMARY KEY,
                    name VARCHAR(255),
                    shortcut VARCHAR(255),
                    url VARCHAR(255),
                    type VARCHAR(255)
                );
                """)
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Table created" + Style.RESET_ALL)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Table not created" + Style.RESET_ALL)
# Out:
# SUCCESS: Table created

# %%
# Create dataframe from JSON object

df_artist = pd.DataFrame.from_dict(napster_json['artists'])
df_artist.head()
# Out:
#      type         id                                            href  \
# 0  artist  art.67317  https://api.napster.com/v2.2/artists/art.67317
#
#           name     shortcut      amg  \
# 0  Johnny Cash  johnny-cash  1837021
#
#                                               blurbs  \
# 0  [Cash's trademark baritone growl and disdainfu...
#
#                                                 bios  \
# 0  [{'title': 'Napster                           ...
#
#                                          albumGroups  \
# 0  {'compilations': ['alb.654799620', 'alb.654798...
#
#                                                links
# 0  {'albums': {'href': 'https://api.napster.com/v...

# %%
# Create a list of columns to drop

columns_table = ['id', 'name', 'shortcut', 'href', 'type']

# Create a list of columns to keep
for column in df_artist.columns:
    if column not in columns_table:
        df_artist.drop(column, axis=1, inplace=True)

# %%
df_artist.head()
# Out:
#      type         id                                            href  \
# 0  artist  art.67317  https://api.napster.com/v2.2/artists/art.67317
#
#           name     shortcut
# 0  Johnny Cash  johnny-cash

# %%
# Deliver the dataframe to the database

try:
    for index, row in df_artist.iterrows():
        cur.execute(f"""
                    INSERT INTO {personal_schema}.artist (id, name, shortcut, url, type)
                    VALUES ('{row['id']}', '{row['name']}', '{row['shortcut']}', '{row['href']}', '{row['type']}');
                    """)
        conn.commit()
        print(Back.BLACK + Fore.GREEN + "SUCCESS: Dataframe delivered to database" + Style.RESET_ALL)
except Exception as e:
    print(e)
    print(Back.BLACK + Fore.RED + "ERROR: Dataframe not delivered to database" + Style.RESET_ALL)
# Out:
# SUCCESS: Dataframe delivered to database

# %%
# Test and bring back the data from the database

try:
    cur.execute(f"SELECT * FROM {personal_schema}.artist;")
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Dataframe delivered to database" + Style.RESET_ALL)
    for row in cur.fetchall():
        print(row)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Dataframe not delivered to database" + Style.RESET_ALL)
# Out:
# SUCCESS: Dataframe delivered to database
# ('art.67317', 'Johnny Cash', 'johnny-cash', 'https://api.napster.com/v2.2/artists/art.67317', 'artist')
