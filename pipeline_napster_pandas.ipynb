# %% [markdown]
# # Entregable # 1

# %%
from colorama import Back, Fore, Style
import pandas as pd
import requests
import psycopg2
import random
import os

# %%
# Function that requests over HTTP a JSON object from a given URL

JSON = int | str | float | bool | None | dict[str, "JSON"] | list["JSON"]
JSONObject = dict[str, JSON]

def http_get_sync(url: str) -> JSONObject:
    """Synchronously performs an HTTP GET request and returns the JSON response."""
    try :
        print(Back.BLACK + Fore.CYAN + "GET: " + url + Style.RESET_ALL)
        return requests.get(url).json()
    except:
        print(Back.BLACK + Fore.RED + "ERROR: " + url + Style.RESET_ALL)
        return {}

# %%
# The limit parameters for the API calls

API_KEY = os.environ.get("NAPSTER_API_KEY")
OFFSET = 1000  # Number of artists to seed in db

# %%
# The URL for the API call

# artist_page_offset = 116 # johnny-cash 212 Bob Dylan
artist_page_offset = random.randint(0, OFFSET)
napster_url = f'https://napi-v2-2-cloud-run-b3gtd5nmxq-uw.a.run.app/v2.2/artists/top{API_KEY}&limit=1&offset={artist_page_offset}'

# %%
# Get the JSON object from the URL

napster_json = http_get_sync(napster_url)
# Out:
# GET: https://napi-v2-2-cloud-run-b3gtd5nmxq-uw.a.run.app/v2.2/artists/top?apikey=MjZkYmFhZTctMjFkZi00NjY3LWEwNGMtZDYzNmQ4YmM3OThi&limit=1&offset=116

# %%
napster_json
# Out:
# {'artists': [{'type': 'artist',
#    'id': 'art.22714272',
#    'href': 'https://api.napster.com/v2.2/artists/art.22714272',
#    'name': 'Zac Brown Band',
#    'shortcut': 'zac-brown-band',
#    'amg': '1607717',
#    'blurbs': ["Brown's laid-back songs roll bits of harmony-filled country, jam and rock into a celebration of all things Southern.",
#     'Zac Brown Band often perform upwards of 200 shows a year! Talk about a road trip.',
#     'Zac Brown Band finally found a mass audience when their "Chicken Fried" song hit the charts.',
#     'The Zac Brown Band have toured with the Allman Brothers, Willie Nelson, Sugarland and Travis Tritt, among others.'],
#    'bios': [{'title': 'Bebop Digital',
#      'author': 'Bebop Digital',
#      'publishDate': '',
#      'bio': 'Zac Brown entertained audiences for years as a solo artist, winning people over with his deft flat-picking and original songs. Eventually, Brown added band members John Hopkins (bass) and Jimmy De Martini (fiddle) to form the Zac Brown Band; the trio expanded to a five-piece when Chris Fryar (drums) and Coy Bowles (guitar/organ) joined. The quintet employs an aggressive tour philosophy (often playing upwards of 200 shows a year) and has opened for the Allman Brothers, Willie Nelson, Travis Tritt and Sugarland, among others. Their grassroots approach to music has won them legions of loyal fans throughout the South, especially in Brown\'s home state of Georgia. The band\'s self-financed debut, <I>Home Grown</I>, was released at the end of 2005, and the live effort <I>Live From the Rock Bus Tour</I> followed in 2007. <I>The Foundation</I> was released in 2008, producing the Southern celebratory single "Chicken Fried," which made its way to the country charts.'}],
#    'albumGroups': {'others': ['alb.754964472',
#      'alb.691549714',
#      'alb.772387353',
#      'alb.633829574',
#      'alb.603653979',
#      'alb.280733703',
#      'alb.610058955',
#      'alb.397071528',
#      'alb.284811364',
#      'alb.254224415',
#      'alb.229629859',
#      'alb.162495489',
#      'alb.396613197',
#      'alb.609200707',
#      'alb.162378200',
#      'alb.108372594',
#      'alb.109870102',
#      'alb.396392373',
#      'alb.608877878',
#      'alb.63439311',
#      'alb.58367959',
#      'alb.49804217',
#      'alb.42484205',
#      'alb.329389513',
#      'alb.56174645',
#      'alb.56169516',
#      'alb.57653629',
#      'alb.57649880',
#      'alb.140706214',
#      'alb.140456431',
#      'alb.140706141',
#      'alb.140495723',
#      'alb.140564391',
#      'alb.195065324'],
#     'compilations': ['alb.753965925',
#      'alb.615486791',
#      'alb.596303012',
#      'alb.580830887',
#      'alb.580831634',
#      'alb.581057805',
#      'alb.580873163',
#      'alb.576268374',
#      'alb.573453795',
#      'alb.571559080',
#      'alb.568627209',
#      'alb.566090592',
#      'alb.565831774',
#      'alb.563856660',
#      'alb.537342610',
#      'alb.538558111',
#      'alb.521015036',
#      'alb.514108708',
#      'alb.514106788',
#      'alb.514131609',
#      'alb.512139920',
#      'alb.512657985',
#      'alb.492722874',
#      'alb.501967793',
#      'alb.489599267',
#      'alb.491830006',
#      'alb.482655528',
#      'alb.482353392',
#      'alb.482655616',
#      'alb.482937690',
#      'alb.479185317',
#      'alb.480368865',
#      'alb.478594456',
#      'alb.476326131',
#      'alb.474577659',
#      'alb.480173311',
#      'alb.472467518',
#      'alb.472498386',
#      'alb.471612771',
#      'alb.471440969',
#      'alb.466374503',
#      'alb.468274314',
#      'alb.467895937',
#      'alb.465342335',
#      'alb.464344047',
#      'alb.462768997',
#      'alb.452842640',
#      'alb.450862727',
#      'alb.450785274',
#      'alb.447375543',
#      'alb.445057164',
#      'alb.437929643',
#      'alb.436749738',
#      'alb.441379281',
#      'alb.436490594',
#      'alb.437376435',
#      'alb.392536760',
#      'alb.437580386',
#      'alb.432222948',
#      'alb.429142783',
#      'alb.424150256',
#      'alb.429630323',
#      'alb.421206898',
#      'alb.418890534',
#      'alb.418671187',
#      'alb.420591128',
#      'alb.421065564',
#      'alb.434893311',
#      'alb.417501210',
#      'alb.410147493',
#      'alb.411021521',
#      'alb.413643913',
#      'alb.405867522',
#      'alb.402214504',
#      'alb.398300199',
#      'alb.397644182',
#      'alb.396631306',
#      'alb.395654230',
#      'alb.392142969',
#      'alb.386978062',
#      'alb.390669498',
#      'alb.388378858',
#      'alb.388377350',
#      'alb.386610461',
#      'alb.608701312',
#      'alb.383979899',
#      'alb.379968279',
#      'alb.381642340',
#      'alb.424424424',
#      'alb.376390246',
#      'alb.377656325',
#      'alb.375813071',
#      'alb.375793768',
#      'alb.372935792',
#      'alb.372137602',
#      'alb.369786170',
#      'alb.368438465',
#      'alb.364677231',
#      'alb.369587406',
#      'alb.367927936',
#      'alb.428841221',
#      'alb.424951726',
#      'alb.367912106',
#      'alb.360685862',
#      'alb.363042619',
#      'alb.355435472',
#      'alb.355415999',
#      'alb.353839107',
#      'alb.349917976',
#      'alb.350156829',
#      'alb.353507251',
#      'alb.428840375',
#      'alb.347212985',
#      'alb.342136616',
#      'alb.341119692',
#      'alb.335583361',
#      'alb.336530626',
#      'alb.337653144',
#      'alb.338232582',
#      'alb.332062145',
#      'alb.336560175',
#      'alb.336567519',
#      'alb.336576173',
#      'alb.464257430',
#      'alb.330246484',
#      'alb.330819556',
#      'alb.332631711',
#      'alb.332883627',
#      'alb.330271711',
#      'alb.330425248',
#      'alb.325960439',
#      'alb.324253252',
#      'alb.323464111',
#      'alb.323263873',
#      'alb.323605027',
#      'alb.318562800',
#      'alb.319057220',
#      'alb.318790265',
#      'alb.318781433',
#      'alb.319191743',
#      'alb.319147275',
#      'alb.318119232',
#      'alb.317909352',
#      'alb.317430409',
#      'alb.317344899',
#      'alb.317396959',
#      'alb.316950391',
#      'alb.317172639',
#      'alb.316295626',
#      'alb.316355702',
#      'alb.316247749',
#      'alb.316247828',
#      'alb.317078031',
#      'alb.317077897',
#      'alb.316230291',
#      'alb.316229952',
#      'alb.316334565',
#      'alb.314868038',
#      'alb.314830849',
#      'alb.316334669',
#      'alb.314867986',
#      'alb.316355623',
#      'alb.315604585',
#      'alb.316340811',
#      'alb.316317041',
#      'alb.315604752',
#      'alb.315635052',
#      'alb.317037261',
#      'alb.312547224',
#      'alb.312359263',
#      'alb.312512513',
#      'alb.309495605',
#      'alb.309524685',
#      'alb.309264368',
#      'alb.308160229',
#      'alb.308137013',
#      'alb.308145497',
#      'alb.305543172',
#      'alb.428651591',
#      'alb.306763512',
#      'alb.306556390',
#      'alb.306556823',
#      'alb.306224937',
#      'alb.305254256',
#      'alb.304630152',
#      'alb.303247460',
#      'alb.304629715',
#      'alb.302833286',
#      'alb.304624971',
#      'alb.304622473',
#      'alb.304630252',
#      'alb.599448587',
#      'alb.659895840',
#      'alb.464257172',
#      'alb.281324932',
#      'alb.279182878',
#      'alb.345550131',
#      'alb.272688945',
#      'alb.270720861',
#      'alb.270747165',
#      'alb.270701949',
#      'alb.268940956',
#      'alb.267175448',
#      'alb.267175553',
#      'alb.268125348',
#      'alb.265338177',
#      'alb.264432933',
#      'alb.264311602',
#      'alb.264311660',
#      'alb.263722875',
#      'alb.613018212',
#      'alb.263527414',
#      'alb.262831804',
#      'alb.267907510',
#      'alb.268124741',
#      'alb.262755345',
#      'alb.269437099',
#      'alb.262355817',
#      'alb.269424063',
#      'alb.261117050',
#      'alb.261101328',
#      'alb.256681088',
#      'alb.256680927',
#      'alb.254224469',
#      'alb.254228700',
#      'alb.254228604',
#      'alb.322100742',
#      'alb.252335117',
#      'alb.428381614',
#      'alb.248395825',
#      'alb.248424446',
#      'alb.245679235',
#      'alb.245700824',
#      'alb.236816997',
#      'alb.230992734',
#      'alb.244810988',
#      'alb.460474999',
#      'alb.206203853',
#      'alb.192469229',
#      'alb.428620794',
#      'alb.439733082',
#      'alb.193100992',
#      'alb.178176772',
#      'alb.193729461',
#      'alb.193765553',
#      'alb.193765191',
#      'alb.127661873',
#      'alb.193728542',
#      'alb.70726987',
#      'alb.194743045',
#      'alb.65016353',
#      'alb.61760152',
#      'alb.108404867',
#      'alb.194732431',
#      'alb.105991629',
#      'alb.54732404',
#      'alb.50005436',
#      'alb.50005480',
#      'alb.126651606',
#      'alb.46403210',
#      'alb.50448130',
#      'alb.43945386',
#      'alb.55345859',
#      'alb.333032104',
#      'alb.55443825',
#      'alb.40287802',
#      'alb.50597242',
#      'alb.56457185',
#      'alb.31728963',
#      'alb.320893981',
#      'alb.55469673',
#      'alb.193115101',
#      'alb.111324265',
#      'alb.562978690'],
#     'singlesAndEPs': ['alb.699206269',
#      'alb.699691671',
#      'alb.695571034',
#      'alb.689650493',
#      'alb.682261648',
#      'alb.676330065',
#      'alb.612281640',
#      'alb.612303789',
#      'alb.607141901',
#      'alb.607153356',
#      'alb.600744836',
#      'alb.600800747',
#      'alb.595386085',
#      'alb.595379455',
#      'alb.588825484',
#      'alb.588822402',
#      'alb.479335082',
#      'alb.477653373',
#      'alb.414998485',
#      'alb.435615218',
#      'alb.400406061',
#      'alb.396913900',
#      'alb.393371999',
#      'alb.345510380',
#      'alb.339468209',
#      'alb.270443973',
#      'alb.260247168',
#      'alb.258818340',
#      'alb.257806957',
#      'alb.254354089',
#      'alb.250964129',
#      'alb.470335445',
#      'alb.220419347',
#      'alb.208866256',
#      'alb.208888058',
#      'alb.581343625',
#      'alb.185315950',
#      'alb.185347818',
#      'alb.180421241',
#      'alb.180604320',
#      'alb.180604721',
#      'alb.180421246',
#      'alb.174263213',
#      'alb.174342120',
#      'alb.145581275',
#      'alb.611022684',
#      'alb.135609559',
#      'alb.61188034',
#      'alb.39932239',
#      'alb.428710016',
#      'alb.29479033',
#      'alb.27557903',
#      'alb.24023912'],
#     'main': ['alb.618170464',
#      'alb.618195013',
#      'alb.703661857',
#      'alb.407465597',
#      'alb.435615109',
#      'alb.464187400',
#      'alb.261283373',
#      'alb.410969978',
#      'alb.470332266',
#      'alb.185315904',
#      'alb.185130243',
#      'alb.359591859',
#      'alb.581343550',
#      'alb.595633076',
#      'alb.166291441',
#      'alb.428827473',
#      'alb.62061437',
#      'alb.411209409',
#      'alb.426271978',
#      'alb.426284841',
#      'alb.40811301',
#      'alb.54341001',
#      'alb.54343232',
#      'alb.425148935',
#      'alb.427855995',
#      'alb.436921997',
#      'alb.33132675',
#      'alb.423964424',
#      'alb.428652555',
#      'alb.427883381',
#      'alb.24285420',
#      'alb.434954143',
#      'alb.23703436']},
#    'links': {'albums': {'href': 'https://api.napster.com/v2.2/artists/art.22714272/albums'},
#     'images': {'href': 'https://api.napster.com/v2.2/artists/art.22714272/images'},
#     'posts': {'href': 'https://api.napster.com/v2.2/artists/art.22714272/posts'},
#     'topTracks': {'href': 'https://api.napster.com/v2.2/artists/art.22714272/tracks/top'},
#     'genres': {'ids': ['g.407', 'g.8', 'g.350', 'g.408'],
#      'href': 'https://api.napster.com/v2.2/genres/g.407,g.8,g.350,g.408'},
#     'stations': {'ids': ['sas.22714272'],
#      'href': 'https://api.napster.com/v2.2/stations/sas.22714272'},
#     'contemporaries': {'ids': ['art.39814547',
#       'art.540',
#       'art.5119359',
#       'art.7292806',
#       'art.7675527',
#       'art.10346369',
#       'art.16550565',
#       'art.31347818',
#       'art.39801162',
#       'art.8330',
#       'art.9364',
#       'art.34505',
#       'art.44564',
#       'art.56627',
#       'art.66465',
#       'art.14435557',
#       'art.20450054',
#       'art.21067632'],
#      'href': 'https://api.napster.com/v2.2/artists/art.39814547,art.540,art.5119359,art.7292806,art.7675527,art.10346369,art.16550565,art.31347818,art.39801162,art.8330,art.9364,art.34505,art.44564,art.56627,art.66465,art.14435557,art.20450054,art.21067632'},
#     'followers': {'ids': ['art.263191163', 'art.137815008'],
#      'href': 'https://api.napster.com/v2.2/artists/art.263191163,art.137815008'},
#     'influences': {'ids': ['art.4389',
#       'art.61525',
#       'art.60982',
#       'art.55136',
#       'art.503',
#       'art.1046',
#       'art.4174',
#       'art.4344',
#       'art.6421',
#       'art.38969',
#       'art.39520',
#       'art.39595',
#       'art.40249',
#       'art.43391',
#       'art.48637',
#       'art.62051',
#       'art.5873',
#       'art.6430'],
#      'href': 'https://api.napster.com/v2.2/artists/art.4389,art.61525,art.60982,art.55136,art.503,art.1046,art.4174,art.4344,art.6421,art.38969,art.39520,art.39595,art.40249,art.43391,art.48637,art.62051,art.5873,art.6430'},
#     'relatedProjects': {'ids': ['art.270443981',
#       'art.238101262',
#       'art.7094212'],
#      'href': 'https://api.napster.com/v2.2/artists/art.270443981,art.238101262,art.7094212'}}}],
#  'meta': {'totalCount': 1000, 'returnedCount': 1}}

# %%
# Get all the keys inside artist object
for key in napster_json['artists'][0].keys():
    print(key)
# Out:
# type
# id
# href
# name
# shortcut
# amg
# blurbs
# bios
# albumGroups
# links

# %%
# Check shortcut for artist name
napster_json['artists'][0]['shortcut']
# Out:
# 'zac-brown-band'

# %% [markdown]
# # Creating Table
#
# The table for the artist, creates an Artist. Each artist has an ID, type, blurbs, name, hred and shorcut.
#
# ## Artist Table
#
# ![Artist Table](images/artist_table.png)
#
# # Data Structures
#
# id = string
# type = string
# href = string
# name = string
# shortcut = string

# %%
# Import environment variables

host = os.environ['HOST']
port = os.environ['PORT']
user = os.environ['USER']
password = os.environ['PASSWORD']
database = os.environ['DATABASE']

# %%
# Create a connection to the database

try:
    conn = psycopg2.connect(
        host=host,
        port=port,
        user=user,
        password=password,
        database=database
    )
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Connection to database" + Style.RESET_ALL)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Connection to database" + Style.RESET_ALL)
# Out:
# SUCCESS: Connection to database

# %%
# Create a cursor to execute SQL commands

try:
    cur = conn.cursor()
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Cursor created" + Style.RESET_ALL)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Cursor not created" + Style.RESET_ALL)
# Out:
# SUCCESS: Cursor created

# %%
# Check the connection
personal_schema = os.environ['PERSONAL_SCHEMA']

#  Check schema exists from CODER
cur.execute(f"SELECT * FROM information_schema.tables WHERE table_schema = '{personal_schema}';")
print(cur.fetchall())
# Out:
# [('data-engineer-database', 'marm1984_coderhouse', 'artist_napster', 'BASE TABLE', None, None, None, None, None), ('data-engineer-database', 'marm1984_coderhouse', 'artist', 'BASE TABLE', None, None, None, None, None)]

# %%
# Drop table if exists

cur.execute(f"DROP TABLE IF EXISTS {personal_schema}.artist;")

# %%
# Create a table for artists

try:
    cur.execute(f"""
                CREATE TABLE IF NOT EXISTS {personal_schema}.artist (
                    id VARCHAR(255) PRIMARY KEY,
                    name VARCHAR(255),
                    shortcut VARCHAR(255),
                    url VARCHAR(255),
                    type VARCHAR(255)
                );
                """)
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Table created" + Style.RESET_ALL)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Table not created" + Style.RESET_ALL)
# Out:
# SUCCESS: Table created

# %%
# Create dataframe from JSON object

df_artist = pd.DataFrame.from_dict(napster_json['artists'])
df_artist.head()
# Out:
#      type            id                                               href  \
# 0  artist  art.22714272  https://api.napster.com/v2.2/artists/art.22714272
#
#              name        shortcut      amg  \
# 0  Zac Brown Band  zac-brown-band  1607717
#
#                                               blurbs  \
# 0  [Brown's laid-back songs roll bits of harmony-...
#
#                                                 bios  \
# 0  [{'title': 'Bebop Digital', 'author': 'Bebop D...
#
#                                          albumGroups  \
# 0  {'others': ['alb.754964472', 'alb.691549714', ...
#
#                                                links
# 0  {'albums': {'href': 'https://api.napster.com/v...

# %%
# Create a list of columns to drop

columns_table = ['id', 'name', 'shortcut', 'href', 'type']

# Create a list of columns to keep
for column in df_artist.columns:
    if column not in columns_table:
        df_artist.drop(column, axis=1, inplace=True)

# %%
df_artist.head()
# Out:
#      type            id                                               href  \
# 0  artist  art.22714272  https://api.napster.com/v2.2/artists/art.22714272
#
#              name        shortcut
# 0  Zac Brown Band  zac-brown-band

# %%
# Deliver the dataframe to the database

try:
    for index, row in df_artist.iterrows():
        cur.execute(f"""
                    INSERT INTO {personal_schema}.artist (id, name, shortcut, url, type)
                    VALUES ('{row['id']}', '{row['name']}', '{row['shortcut']}', '{row['href']}', '{row['type']}');
                    """)
        conn.commit()
        print(Back.BLACK + Fore.GREEN + "SUCCESS: Dataframe delivered to database" + Style.RESET_ALL)
except Exception as e:
    print(e)
    print(Back.BLACK + Fore.RED + "ERROR: Dataframe not delivered to database" + Style.RESET_ALL)
# Out:
# SUCCESS: Dataframe delivered to database

# %%
# Test and bring back the data from the database

try:
    cur.execute(f"SELECT * FROM {personal_schema}.artist;")
    print(Back.BLACK + Fore.GREEN + "SUCCESS: Dataframe delivered to database" + Style.RESET_ALL)
    for row in cur.fetchall():
        print(row)
except:
    print(Back.BLACK + Fore.RED + "ERROR: Dataframe not delivered to database" + Style.RESET_ALL)
# Out:
# SUCCESS: Dataframe delivered to database
# ('art.22714272', 'Zac Brown Band', 'zac-brown-band', 'https://api.napster.com/v2.2/artists/art.22714272', 'artist')
